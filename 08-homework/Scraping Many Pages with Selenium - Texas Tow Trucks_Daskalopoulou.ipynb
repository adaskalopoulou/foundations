# %% [markdown]
# # Texas Tow Trucks (`.apply` and Selenium)
#
# We're going to scrape some [tow trucks in Texas](https://www.tdlr.texas.gov/tools_search/).
#
# Try searching for the TLDR Number `006179570C`.

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### What URL will Selenium be starting on?
#
# - Tip: The answer is *not* `https://www.tdlr.texas.gov/tools_search/`

# %%
# This is a link for a new searc: https://www.tdlr.texas.gov/tools_search/mccs_search.asp

# %% [markdown]
# ### Why are you using Selenium for this?

# %%
# to navigate a webpage pretending that we use the browser manually

# %% [markdown]
# ## Scrape this page
#
# Scrape this page, displaying the
#
# - The business name
# - Phone number
# - License status
# - Physical address
#
# - *TIP: For physical address, **ask me on the board** and I'll give you a secret trick about situations like this.*

# %%
import selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")

# %%
driver.find_element_by_xpath('//*[@id="mcrdata"]').send_keys("006179570C")

# %%
driver.find_element_by_xpath('//*[@id="searchinfo"]').submit()

# %%
name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]')
print(name.text)
# Out:
# Name:   B.D. SMITH TOWING

# %%
phone = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]')
print(phone.text)
# Out:
# Phone:   8173330706

# %%
status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]/font/font')
print(status.text)
# Out:
# Active

# %%
all_right = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]')
print(all_right.text)
# Out:
# Carrier Type:  Tow Truck Company
# Number of Active Tow Trucks:   0
#
# Address Information
# Mailing:
# 13619 BRETT JACKSON RD
# FORT WORTH, TX. 76179
#
# Physical:
# 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179

# %%
physical = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]/strong[4]')
print(physical.text)
# Out:
# Physical:

# %%
all_right = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]')
print(all_right.text)
# Out:
# Carrier Type:  Tow Truck Company
# Number of Active Tow Trucks:   0
#
# Address Information
# Mailing:
# 13619 BRETT JACKSON RD
# FORT WORTH, TX. 76179
#
# Physical:
# 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179

# %%
print(all_right.text.split(":")[-1])
# Out:
# 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179

# %% [markdown]
# # Using .apply to find data about SEVERAL tow truck companies
#
# The file `trucks-subset.csv` has information about the trucks, we'll use it to find the pages to scrape.
#
# ### Open up `trucks-subset.csv` and save it into a dataframe

# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("trucks-subset.csv")
df.head()
# Out:
#           IDs
# 0  006507931C
# 1  006179570C
# 2  006502097C

# %% [markdown]
# ### Open up `trucks-subset.csv` in a text editor, then look at your dataframe. Is something different about them? If so, make them match.
#
# - *TIP: I can help with this.*

# %%
# I named the column id

# %% [markdown]
# ## Use `.apply` to go through each row of the dataset, printing out information about each tow truck company.
#
# - The business name
# - Phone number
# - License status
# - Physical address
#
# Just print it out for now.
#
# - *TIP: use .apply and a function*
# - *TIP: If you need help with .apply, look at the "Using apply in pandas" notebook *

# %%
def IDs(row):
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit()
    business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]').text.strip()    
    phone_number = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]').text.strip()
    license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]').text.strip()
    physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]').text.split(":")[-1].strip()
    print(business_name)
    print(phone_number)
    print(license_status)
    print(physical_address)
    print("-----")
    
driver = webdriver.Chrome()
df.apply(IDs,axis=1)
# Out:
# Name:   AUGUSTUS E SMITH
# Phone:   9032276464
# Status:  Active
# 103 N MAIN ST
# BONHAM, TX. 75418
# -----
# Name:   B.D. SMITH TOWING
# Phone:   8173330706
# Status:  Active
# 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179
# -----
# Name:   BARRY MICHAEL SMITH
# Phone:   8066544404
# Status:  Active
# 4501 W CEMETERY RD
# CANYON, TX. 79015
# -----
# 0    None
# 1    None
# 2    None
# dtype: object

# %% [markdown]
# ## Scrape the following information for each row of the dataset, and save it into new columns in your dataframe.
#
# - The business name
# - Phone number
# - License status
# - Physical address
#
# It's basically what we did before, but using the function a little differently.
#
# - *TIP: Use .apply and a function*
# - *TIP: Remember to use `return`*

# %%
def IDs(row):
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit()
    business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]').text.strip()    
    phone_number = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]').text.strip()
    license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]').text.strip()
    physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]').text.split(":")[-1]
    

    return pd.Series({
        'business_name': business_name,
        'phone_number': phone_number,
        'license_status': license_status, 
        'physical_address': physical_address
    })


driver = webdriver.Chrome()
df = df.apply(IDs,axis=1).join(df)

# %%
df
# Out:
#                  business_name   license_status         phone_number  \
# 0     Name:   AUGUSTUS E SMITH  Status:  Active  Phone:   9032276464
# 1    Name:   B.D. SMITH TOWING  Status:  Active  Phone:   8173330706
# 2  Name:   BARRY MICHAEL SMITH  Status:  Active  Phone:   8066544404
#
#                                    physical_address         IDs
# 0                \n103 N MAIN ST\nBONHAM, TX. 75418  006507931C
# 1  \n13619 BRETT JACKSON RD.\nFORT WORTH, TX. 76179  006179570C
# 2           \n4501 W CEMETERY RD\nCANYON, TX. 79015  006502097C

# %% [markdown]
# ### Save your dataframe as a CSV

# %%
df.to_csv('trucks-subset-3first.csv', index=False)

# %% [markdown]
# ### Re-open your dataframe to confirm you didn't save any extra weird columns

# %%
pd.read_csv('trucks-subset-3first.csv')
# Out:
#                  business_name   license_status         phone_number  \
# 0     Name:   AUGUSTUS E SMITH  Status:  Active  Phone:   9032276464
# 1    Name:   B.D. SMITH TOWING  Status:  Active  Phone:   8173330706
# 2  Name:   BARRY MICHAEL SMITH  Status:  Active  Phone:   8066544404
#
#                                    physical_address         IDs
# 0                \n103 N MAIN ST\nBONHAM, TX. 75418  006507931C
# 1  \n13619 BRETT JACKSON RD.\nFORT WORTH, TX. 76179  006179570C
# 2           \n4501 W CEMETERY RD\nCANYON, TX. 79015  006502097C

# %% [markdown]
# ## Repeat this process for the entire `tow-trucks.csv` file

# %%
df_all = pd.read_csv("tow-trucks.csv")
df_all
# Out:
#            IDs
# 0   006507931C
# 1   006179570C
# 2   006502097C
# 3   006494912C
# 4   0649468VSF
# 5   006448786C
# 6   0648444VSF
# 7   0651667VSF
# 8   006017767C
# 9   006495492C
# 10  006518521C
# 11  006521662C
# 12  006482451C
# 13  0646264VSF
# 14  0650690VSF
# 15  006505010C
# 16  0000210VSF
# 17  005029369C
# 18  006410509C
# 19  0643482VSF

# %%
def IDs(row):
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit()
    business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]').text.strip()    
    phone_number = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]').text.strip()
    license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]').text.strip()
    physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]').text.split(":")[-1].strip()
    print(business_name)
    print(phone_number)
    print(license_status)
    print(physical_address)
    print("-----")

driver = webdriver.Chrome()
df_all.apply(IDs,axis=1) 
driver.close()
# Out:
# Name:   AUGUSTUS E SMITH
# Phone:   9032276464
# Status:  Active
# 103 N MAIN ST
# BONHAM, TX. 75418
# -----
# Name:   B.D. SMITH TOWING
# Phone:   8173330706
# Status:  Active
# 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179
# -----
# Name:   BARRY MICHAEL SMITH
# Phone:   8066544404
# Status:  Active
# 4501 W CEMETERY RD
# CANYON, TX. 79015
# -----
# Name:   HEATH SMITH
# Phone:   940-552-0687
# Status:  Expired
# 1529 WILBARGER ST
# VERNON, TX. 76384
# -----
# Name:   HEATH SMITH
# Phone:   9405520687
# Status:  Expired
# 1529 WILBARGER ST
# VERNON, TX. 76384
# -----
# Name:   HYSMITH AUTOMOTIVE
# Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# Status:  Active
# 1210 US 380 BYPASS
# GRAHAM, TX. 76450
# -----
# Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# Owner/Officer:   WILLIAM THOMAS HYSMITH / PRESIDENT
# Status:  Expired
# 927 LOVING HWY
# GRAHAM, TX. 76450
# -----
# Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# Status:  Active
# 1210 380 BYPASS
# GRAHAM, TX. 76450
# -----
# Name:   JEFF & WENDY SMITH
# Owner/Officer:   WENDY SMITH / PARTNER
# Status:  Expired
# 10842 FM 2138 N
# JACKSONVILLE, TX. 75766
# -----
# Name:   JEFF SMITH
# Phone:   8324354670
# Status:  Active
# 4338 HARVEY RD
# CROSBY, TX. 77532
# -----
# Name:   LUTHER SMITH
# Phone:   281-838-9435
# Status:  Active
# 20001 FM 2100 RD
# CROSBY, TX. 77532
# -----
# Name:   MAURICE SMITH
# Phone:   7134544462
# Status:  Active
# 5505 SAVANNAH WOODS LN
# ROSHARON, TX. 77583
# -----
# Name:   METRO LOCKSMITHS INC
# Owner/Officer:   SOCORRO M ARREOLA / OWNER
# Status:  Active
# 200 S WALL ST
# ITASCA, TX. 76055
# -----
# Name:   AUGUSTUS E SMITH
# Phone:   9032276464
# Status:  Active
# 103 N MAIN ST
# BONHAM, TX. 75418
# -----
# Name:   B.D. SMITH TOWING
# Phone:   8173330706
# Status:  Active
# 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179
# -----
# Name:   BARRY MICHAEL SMITH
# Phone:   8066544404
# Status:  Active
# 4501 W CEMETERY RD
# CANYON, TX. 79015
# -----
# Name:   HEATH SMITH
# Phone:   940-552-0687
# Status:  Expired
# 1529 WILBARGER ST
# VERNON, TX. 76384
# -----
# Name:   HEATH SMITH
# Phone:   9405520687
# Status:  Expired
# 1529 WILBARGER ST
# VERNON, TX. 76384
# -----
# Name:   HYSMITH AUTOMOTIVE
# Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# Status:  Active
# 1210 US 380 BYPASS
# GRAHAM, TX. 76450
# -----
# Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# Owner/Officer:   WILLIAM THOMAS HYSMITH / PRESIDENT
# Status:  Expired
# 927 LOVING HWY
# GRAHAM, TX. 76450
# -----
# Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# Status:  Active
# 1210 380 BYPASS
# GRAHAM, TX. 76450
# -----
# Name:   JEFF & WENDY SMITH
# Owner/Officer:   WENDY SMITH / PARTNER
# Status:  Expired
# 10842 FM 2138 N
# JACKSONVILLE, TX. 75766
# -----
# Name:   JEFF SMITH
# Phone:   8324354670
# Status:  Active
# 4338 HARVEY RD
# CROSBY, TX. 77532
# -----
# Name:   LUTHER SMITH
# Phone:   281-838-9435
# Status:  Active
# 20001 FM 2100 RD
# CROSBY, TX. 77532
# -----
# Name:   MAURICE SMITH
# Phone:   7134544462
# Status:  Active
# 5505 SAVANNAH WOODS LN
# ROSHARON, TX. 77583
# -----
# Name:   METRO LOCKSMITHS INC
# Owner/Officer:   SOCORRO M ARREOLA / OWNER
# Status:  Active
# 200 S WALL ST
# ITASCA, TX. 76055
# -----
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-25-793714036faa> in <module>()
#      15
#      16 driver = webdriver.Chrome()
# ---> 17 df_all.apply(IDs,axis=1)
#      18 driver.close()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# <ipython-input-25-793714036faa> in IDs(row)
#       4     textbox.send_keys(row['IDs'])
#       5     driver.find_element_by_xpath('//*[@id="searchinfo"]').submit()
# ----> 6     business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]').text.strip()
#       7     phone_number = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]').text.strip()
#       8     license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]').text.strip()
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     311             driver.find_element_by_xpath('//div/td[1]')
#     312         """
# --> 313         return self.find_element(by=By.XPATH, value=xpath)
#     314
#     315     def find_elements_by_xpath(self, xpath):
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     789         return self.execute(Command.FIND_ELEMENT, {
#     790             'using': by,
# --> 791             'value': value})['value']
#     792
#     793     def find_elements(self, by=By.ID, value=None):
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     254         response = self.command_executor.execute(driver_command, params)
#     255         if response:
# --> 256             self.error_handler.check_response(response)
#     257             response['value'] = self._unwrap_value(
#     258                 response.get('value', None))
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]"}
#   (Session info: chrome=58.0.3029.110)
#   (Driver info: chromedriver=2.30.477690 (c53f4ad87510ee97b5c3425a14c0e79780cdf262),platform=Mac OS X 10.11.6 x86_64)

# %%
def IDs(row):
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit() 
    try:
        business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]').text.strip()    
        phone_number = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]').text.strip()
        license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]').text.strip()
        physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]').text.split(":")[-1]
        
        return pd.Series({
            'business_name': business_name,
            'phone_number': phone_number,
            'license_status': license_status, 
            'physical_address': physical_address
        })
    except: 
        pass
         
driver = webdriver.Chrome()
df_all = df_all.apply(IDs,axis=1).join(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2c6dd0dd1ddb> in <module>()
#      20
#      21 driver = webdriver.Chrome()
# ---> 22 df_all = df_all.apply(IDs,axis=1).join(df)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4667         # For SparseDataFrame's benefit
#    4668         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4669                                  rsuffix=rsuffix, sort=sort)
#    4670
#    4671     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4682             return merge(self, other, left_on=on, how=how,
#    4683                          left_index=on is None, right_index=True,
# -> 4684                          suffixes=(lsuffix, rsuffix), sort=sort)
#    4685         else:
#    4686             if on is not None:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
#      53                          copy=copy, indicator=indicator)
# ---> 54     return op.get_result()
#      55
#      56
#
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     573
#     574         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 575                                                      rdata.items, rsuf)
#     576
#     577         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    4699         if not lsuffix and not rsuffix:
#    4700             raise ValueError('columns overlap but no suffix specified: %s' %
# -> 4701                              to_rename)
#    4702
#    4703         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index(['business_name', 'license_status', 'phone_number', 'physical_address'], dtype='object')

# %%
# as I am getting an error I will try adding every column one after one

# %%
def IDs(row):
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit() 
    try:
        business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]').text.strip()    
#       phone_number = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]').text.strip()
#         license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]').text.strip()
#         physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]').text.split(":")[-1]
        return business_name
    except: 
        pass
         
driver = webdriver.Chrome()
df_all["business_name"] = df_all.apply(IDs, axis=1)
driver.close()
df_all
# Out:
#            IDs                                  business_name
# 0   006507931C                       Name:   AUGUSTUS E SMITH
# 1   006179570C                      Name:   B.D. SMITH TOWING
# 2   006502097C                    Name:   BARRY MICHAEL SMITH
# 3   006494912C                            Name:   HEATH SMITH
# 4   0649468VSF                            Name:   HEATH SMITH
# 5   006448786C                     Name:   HYSMITH AUTOMOTIVE
# 6   0648444VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 7   0651667VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 8   006017767C                     Name:   JEFF & WENDY SMITH
# 9   006495492C                             Name:   JEFF SMITH
# 10  006518521C                           Name:   LUTHER SMITH
# 11  006521662C                          Name:   MAURICE SMITH
# 12  006482451C                   Name:   METRO LOCKSMITHS INC
# 13  0646264VSF                                           None
# 14  0650690VSF                                           None
# 15  006505010C                          Name:   SAMMY L SMITH
# 16  0000210VSF             Name:   SMITH BRO. WRECKER SERVICE
# 17  005029369C            Name:   SMITH BROS. WRECKER SERVICE
# 18  006410509C           Name:   SMITH TOWING & RECOVERY, LLC
# 19  0643482VSF            Name:   SMITH TOWING & RECOVERY,LLC

# %%
def IDs(row):
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit() 
    try:
      #  business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]').text.strip()    
        phone_number = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]').text.strip()
#         license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]').text.strip()
#         physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]').text.split(":")[-1]
        return phone_number
    except: 
        pass
         
driver = webdriver.Chrome()
df_all["phone_number"] = df_all.apply(IDs, axis=1)
driver.close()
df_all
# Out:
#            IDs                                  business_name  \
# 0   006507931C                       Name:   AUGUSTUS E SMITH
# 1   006179570C                      Name:   B.D. SMITH TOWING
# 2   006502097C                    Name:   BARRY MICHAEL SMITH
# 3   006494912C                            Name:   HEATH SMITH
# 4   0649468VSF                            Name:   HEATH SMITH
# 5   006448786C                     Name:   HYSMITH AUTOMOTIVE
# 6   0648444VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 7   0651667VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 8   006017767C                     Name:   JEFF & WENDY SMITH
# 9   006495492C                             Name:   JEFF SMITH
# 10  006518521C                           Name:   LUTHER SMITH
# 11  006521662C                          Name:   MAURICE SMITH
# 12  006482451C                   Name:   METRO LOCKSMITHS INC
# 13  0646264VSF                                           None
# 14  0650690VSF                                           None
# 15  006505010C                          Name:   SAMMY L SMITH
# 16  0000210VSF             Name:   SMITH BRO. WRECKER SERVICE
# 17  005029369C            Name:   SMITH BROS. WRECKER SERVICE
# 18  006410509C           Name:   SMITH TOWING & RECOVERY, LLC
# 19  0643482VSF            Name:   SMITH TOWING & RECOVERY,LLC
#
#                                          phone_number
# 0                                 Phone:   9032276464
# 1                                 Phone:   8173330706
# 2                                 Phone:   8066544404
# 3                               Phone:   940-552-0687
# 4                                 Phone:   9405520687
# 5    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# 6   Owner/Officer:   WILLIAM THOMAS HYSMITH / PRES...
# 7    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# 8              Owner/Officer:   WENDY SMITH / PARTNER
# 9                                 Phone:   8324354670
# 10                              Phone:   281-838-9435
# 11                                Phone:   7134544462
# 12         Owner/Officer:   SOCORRO M ARREOLA / OWNER
# 13                                               None
# 14                                               None
# 15                                Phone:   3252159496
# 16              Owner/Officer:   GLEN SMITH / PARTNER
# 17              Owner/Officer:   GLEN SMITH / PARTNER
# 18                                Phone:   9362693915
# 19                                Phone:   9362693915

# %%
def IDs(row):
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit() 
    try: 
        rows = driver.find_elements_by_tag_name('tr')
        for row in rows:
            tds = row.find_elements_by_tag_name('td')
            number = tds[-6]
    except: 
        pass
         
driver = webdriver.Chrome()
df_all["number"] = df_all.apply(IDs, axis=1)
driver.close()
df_all
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-59-c64841c525dc> in <module>()
#      13
#      14 driver = webdriver.Chrome()
# ---> 15 df_all["number"] = df_all.apply(IDs, axis=1)
#      16 driver.close()
#      17 df_all
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# <ipython-input-59-c64841c525dc> in IDs(row)
#       1 def IDs(row):
# ----> 2     driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")
#       3     textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
#       4     textbox.send_keys(row['IDs'])
#       5     driver.find_element_by_xpath('//*[@id="searchinfo"]').submit()
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     266         Loads a web page in the current browser session.
#     267         """
# --> 268         self.execute(Command.GET, {'url': url})
#     269
#     270     @property
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     252
#     253         params = self._wrap_value(params)
# --> 254         response = self.command_executor.execute(driver_command, params)
#     255         if response:
#     256             self.error_handler.check_response(response)
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     462         path = string.Template(command_info[1]).substitute(params)
#     463         url = '%s%s' % (self._url, path)
# --> 464         return self._request(command_info[0], url, body=data)
#     465
#     466     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     485                 body = None
#     486             try:
# --> 487                 self._conn.request(method, parsed_url.path, body, headers)
#     488                 resp = self._conn.getresponse()
#     489             except (httplib.HTTPException, socket.error):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in connect(self)
#     934         """Connect to the host and port specified in __init__."""
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     938
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     720
#     721     if err is not None:
# --> 722         raise err
#     723     else:
#     724         raise error("getaddrinfo returns an empty list")
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     711             if source_address:
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             return sock
#     715
#
# OSError: [Errno 49] Can't assign requested address

# %%
# unfortunately I get "None" instead of the phone number.

# %%
def IDs(row):
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit() 
    try:
        #business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]').text.strip()    
        #phone_number = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]').text.strip()
        license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]').text.strip()
        #physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]').text.split(":")[-1]
        return license_status
    except: 
        pass
         
driver = webdriver.Chrome()
df_all["license_status"] = df_all.apply(IDs, axis=1)
driver.close()
df_all
# Out:
#            IDs                                  business_name  \
# 0   006507931C                       Name:   AUGUSTUS E SMITH
# 1   006179570C                      Name:   B.D. SMITH TOWING
# 2   006502097C                    Name:   BARRY MICHAEL SMITH
# 3   006494912C                            Name:   HEATH SMITH
# 4   0649468VSF                            Name:   HEATH SMITH
# 5   006448786C                     Name:   HYSMITH AUTOMOTIVE
# 6   0648444VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 7   0651667VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 8   006017767C                     Name:   JEFF & WENDY SMITH
# 9   006495492C                             Name:   JEFF SMITH
# 10  006518521C                           Name:   LUTHER SMITH
# 11  006521662C                          Name:   MAURICE SMITH
# 12  006482451C                   Name:   METRO LOCKSMITHS INC
# 13  0646264VSF                                           None
# 14  0650690VSF                                           None
# 15  006505010C                          Name:   SAMMY L SMITH
# 16  0000210VSF             Name:   SMITH BRO. WRECKER SERVICE
# 17  005029369C            Name:   SMITH BROS. WRECKER SERVICE
# 18  006410509C           Name:   SMITH TOWING & RECOVERY, LLC
# 19  0643482VSF            Name:   SMITH TOWING & RECOVERY,LLC
#
#                                          phone_number    license_status
# 0                                 Phone:   9032276464   Status:  Active
# 1                                 Phone:   8173330706   Status:  Active
# 2                                 Phone:   8066544404   Status:  Active
# 3                               Phone:   940-552-0687  Status:  Expired
# 4                                 Phone:   9405520687  Status:  Expired
# 5    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER   Status:  Active
# 6   Owner/Officer:   WILLIAM THOMAS HYSMITH / PRES...  Status:  Expired
# 7    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER   Status:  Active
# 8              Owner/Officer:   WENDY SMITH / PARTNER  Status:  Expired
# 9                                 Phone:   8324354670   Status:  Active
# 10                              Phone:   281-838-9435   Status:  Active
# 11                                Phone:   7134544462   Status:  Active
# 12         Owner/Officer:   SOCORRO M ARREOLA / OWNER   Status:  Active
# 13                                               None              None
# 14                                               None              None
# 15                                Phone:   3252159496  Status:  Expired
# 16              Owner/Officer:   GLEN SMITH / PARTNER   Status:  Active
# 17              Owner/Officer:   GLEN SMITH / PARTNER   Status:  Active
# 18                                Phone:   9362693915   Status:  Active
# 19                                Phone:   9362693915   Status:  Active

# %%
def IDs(row):
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit() 
    try:
        #business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]').text.strip()    
        #phone_number = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]').text.strip()
        #license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]').text.strip()
        physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]').text.split(":")[-1]
        return physical_address
    except: 
        pass
         
driver = webdriver.Chrome()
df_all["physical_address"] = df_all.apply(IDs, axis=1)
driver.close()
df_all
# Out:
#            IDs                                  business_name  \
# 0   006507931C                       Name:   AUGUSTUS E SMITH
# 1   006179570C                      Name:   B.D. SMITH TOWING
# 2   006502097C                    Name:   BARRY MICHAEL SMITH
# 3   006494912C                            Name:   HEATH SMITH
# 4   0649468VSF                            Name:   HEATH SMITH
# 5   006448786C                     Name:   HYSMITH AUTOMOTIVE
# 6   0648444VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 7   0651667VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 8   006017767C                     Name:   JEFF & WENDY SMITH
# 9   006495492C                             Name:   JEFF SMITH
# 10  006518521C                           Name:   LUTHER SMITH
# 11  006521662C                          Name:   MAURICE SMITH
# 12  006482451C                   Name:   METRO LOCKSMITHS INC
# 13  0646264VSF                                           None
# 14  0650690VSF                                           None
# 15  006505010C                          Name:   SAMMY L SMITH
# 16  0000210VSF             Name:   SMITH BRO. WRECKER SERVICE
# 17  005029369C            Name:   SMITH BROS. WRECKER SERVICE
# 18  006410509C           Name:   SMITH TOWING & RECOVERY, LLC
# 19  0643482VSF            Name:   SMITH TOWING & RECOVERY,LLC
#
#                                          phone_number    license_status  \
# 0                                 Phone:   9032276464   Status:  Active
# 1                                 Phone:   8173330706   Status:  Active
# 2                                 Phone:   8066544404   Status:  Active
# 3                               Phone:   940-552-0687  Status:  Expired
# 4                                 Phone:   9405520687  Status:  Expired
# 5    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER   Status:  Active
# 6   Owner/Officer:   WILLIAM THOMAS HYSMITH / PRES...  Status:  Expired
# 7    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER   Status:  Active
# 8              Owner/Officer:   WENDY SMITH / PARTNER  Status:  Expired
# 9                                 Phone:   8324354670   Status:  Active
# 10                              Phone:   281-838-9435   Status:  Active
# 11                                Phone:   7134544462   Status:  Active
# 12         Owner/Officer:   SOCORRO M ARREOLA / OWNER   Status:  Active
# 13                                               None              None
# 14                                               None              None
# 15                                Phone:   3252159496  Status:  Expired
# 16              Owner/Officer:   GLEN SMITH / PARTNER   Status:  Active
# 17              Owner/Officer:   GLEN SMITH / PARTNER   Status:  Active
# 18                                Phone:   9362693915   Status:  Active
# 19                                Phone:   9362693915   Status:  Active
#
#                                     physical_address
# 0                 \n103 N MAIN ST\nBONHAM, TX. 75418
# 1   \n13619 BRETT JACKSON RD.\nFORT WORTH, TX. 76179
# 2            \n4501 W CEMETERY RD\nCANYON, TX. 79015
# 3             \n1529 WILBARGER ST\nVERNON, TX. 76384
# 4             \n1529 WILBARGER ST\nVERNON, TX. 76384
# 5            \n1210 US 380 BYPASS\nGRAHAM, TX. 76450
# 6                \n927 LOVING HWY\nGRAHAM, TX. 76450
# 7               \n1210 380 BYPASS\nGRAHAM, TX. 76450
# 8         \n10842 FM 2138 N\nJACKSONVILLE, TX. 75766
# 9                \n4338 HARVEY RD\nCROSBY, TX. 77532
# 10             \n20001 FM 2100 RD\nCROSBY, TX. 77532
# 11     \n5505 SAVANNAH WOODS LN\nROSHARON, TX. 77583
# 12                \n200 S WALL ST\nITASCA, TX. 76055
# 13                                              None
# 14                                              None
# 15              \n355 N 16TH ST\nJUNCTION, TX. 76849
# 16        \n10842 FM 2138 N\nJACKSONVILLE, TX. 75766
# 17        \n10842 FM 2138 N\nJACKSONVILLE, TX. 75766
# 18               \n12741 HWY 84E\nJOAQUIN, TX. 75954
# 19              \n12741 HWY 84 E\nJOAQUIN, TX. 75954

# %%
df_all.to_csv('trucks-subset-all.csv', index=False)

# %%
pd.read_csv('trucks-subset-all.csv')
# Out:
#            IDs                                  business_name  \
# 0   006507931C                       Name:   AUGUSTUS E SMITH
# 1   006179570C                      Name:   B.D. SMITH TOWING
# 2   006502097C                    Name:   BARRY MICHAEL SMITH
# 3   006494912C                            Name:   HEATH SMITH
# 4   0649468VSF                            Name:   HEATH SMITH
# 5   006448786C                     Name:   HYSMITH AUTOMOTIVE
# 6   0648444VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 7   0651667VSF  Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 8   006017767C                     Name:   JEFF & WENDY SMITH
# 9   006495492C                             Name:   JEFF SMITH
# 10  006518521C                           Name:   LUTHER SMITH
# 11  006521662C                          Name:   MAURICE SMITH
# 12  006482451C                   Name:   METRO LOCKSMITHS INC
# 13  0646264VSF                                            NaN
# 14  0650690VSF                                            NaN
# 15  006505010C                          Name:   SAMMY L SMITH
# 16  0000210VSF             Name:   SMITH BRO. WRECKER SERVICE
# 17  005029369C            Name:   SMITH BROS. WRECKER SERVICE
# 18  006410509C           Name:   SMITH TOWING & RECOVERY, LLC
# 19  0643482VSF            Name:   SMITH TOWING & RECOVERY,LLC
#
#                                          phone_number    license_status  \
# 0                                 Phone:   9032276464   Status:  Active
# 1                                 Phone:   8173330706   Status:  Active
# 2                                 Phone:   8066544404   Status:  Active
# 3                               Phone:   940-552-0687  Status:  Expired
# 4                                 Phone:   9405520687  Status:  Expired
# 5    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER   Status:  Active
# 6   Owner/Officer:   WILLIAM THOMAS HYSMITH / PRES...  Status:  Expired
# 7    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER   Status:  Active
# 8              Owner/Officer:   WENDY SMITH / PARTNER  Status:  Expired
# 9                                 Phone:   8324354670   Status:  Active
# 10                              Phone:   281-838-9435   Status:  Active
# 11                                Phone:   7134544462   Status:  Active
# 12         Owner/Officer:   SOCORRO M ARREOLA / OWNER   Status:  Active
# 13                                                NaN               NaN
# 14                                                NaN               NaN
# 15                                Phone:   3252159496  Status:  Expired
# 16              Owner/Officer:   GLEN SMITH / PARTNER   Status:  Active
# 17              Owner/Officer:   GLEN SMITH / PARTNER   Status:  Active
# 18                                Phone:   9362693915   Status:  Active
# 19                                Phone:   9362693915   Status:  Active
#
#                                     physical_address
# 0                 \n103 N MAIN ST\nBONHAM, TX. 75418
# 1   \n13619 BRETT JACKSON RD.\nFORT WORTH, TX. 76179
# 2            \n4501 W CEMETERY RD\nCANYON, TX. 79015
# 3             \n1529 WILBARGER ST\nVERNON, TX. 76384
# 4             \n1529 WILBARGER ST\nVERNON, TX. 76384
# 5            \n1210 US 380 BYPASS\nGRAHAM, TX. 76450
# 6                \n927 LOVING HWY\nGRAHAM, TX. 76450
# 7               \n1210 380 BYPASS\nGRAHAM, TX. 76450
# 8         \n10842 FM 2138 N\nJACKSONVILLE, TX. 75766
# 9                \n4338 HARVEY RD\nCROSBY, TX. 77532
# 10             \n20001 FM 2100 RD\nCROSBY, TX. 77532
# 11     \n5505 SAVANNAH WOODS LN\nROSHARON, TX. 77583
# 12                \n200 S WALL ST\nITASCA, TX. 76055
# 13                                               NaN
# 14                                               NaN
# 15              \n355 N 16TH ST\nJUNCTION, TX. 76849
# 16        \n10842 FM 2138 N\nJACKSONVILLE, TX. 75766
# 17        \n10842 FM 2138 N\nJACKSONVILLE, TX. 75766
# 18               \n12741 HWY 84E\nJOAQUIN, TX. 75954
# 19              \n12741 HWY 84 E\nJOAQUIN, TX. 75954

# %% [markdown]
# ## TRYING TO GET THE RIGHT PHONE NUMBERS

# %%
import pandas as pd
df_test = pd.read_csv("tow-trucks.csv")
df_test
# Out:
#            IDs
# 0   006507931C
# 1   006179570C
# 2   006502097C
# 3   006494912C
# 4   0649468VSF
# 5   006448786C
# 6   0648444VSF
# 7   0651667VSF
# 8   006017767C
# 9   006495492C
# 10  006518521C
# 11  006521662C
# 12  006482451C
# 13  0646264VSF
# 14  0650690VSF
# 15  006505010C
# 16  0000210VSF
# 17  005029369C
# 18  006410509C
# 19  0643482VSF

# %%
from selenium import webdriver
import time

def IDs(row):
    time.sleep(2)
    driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")    
    textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    textbox.send_keys(row['IDs'])
    driver.find_element_by_xpath('//*[@id="searchinfo"]').submit()
    try:
        rows = driver.find_elements_by_tag_name('tr')
        for row in rows:
            tds = row.find_elements_by_tag_name("td")
            number = tds[-6]
            print(number.text)
            print("-----")
    except: 
        pass
    
driver = webdriver.Chrome()    
df_test.apply(IDs,axis=1) 
drive.close()
# Out:
# Phone:   9032276464
# -----
# Phone:   8173330706
# -----
# Phone:   8066544404
# -----
# Phone:   940-552-0687
# -----
# Phone:   9405520687
# -----
# Phone:   940-521-0294
# -----
# Phone:   9405210294
# -----
# Phone:   9405210294
# -----
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-68-85ecb9676e4b> in <module>()
#      19
#      20 driver = webdriver.Chrome()
# ---> 21 df_test.apply(IDs,axis=1)
#      22 drive.close()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# <ipython-input-68-85ecb9676e4b> in IDs(row)
#       4 def IDs(row):
#       5     time.sleep(2)
# ----> 6     driver.get("https://www.tdlr.texas.gov/tools_search/mccs_search.asp")
#       7     textbox = driver.find_element_by_xpath('//*[@id="mcrdata"]')
#       8     textbox.send_keys(row['IDs'])
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     266         Loads a web page in the current browser session.
#     267         """
# --> 268         self.execute(Command.GET, {'url': url})
#     269
#     270     @property
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     252
#     253         params = self._wrap_value(params)
# --> 254         response = self.command_executor.execute(driver_command, params)
#     255         if response:
#     256             self.error_handler.check_response(response)
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     462         path = string.Template(command_info[1]).substitute(params)
#     463         url = '%s%s' % (self._url, path)
# --> 464         return self._request(command_info[0], url, body=data)
#     465
#     466     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     485                 body = None
#     486             try:
# --> 487                 self._conn.request(method, parsed_url.path, body, headers)
#     488                 resp = self._conn.getresponse()
#     489             except (httplib.HTTPException, socket.error):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in connect(self)
#     934         """Connect to the host and port specified in __init__."""
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     938
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     720
#     721     if err is not None:
# --> 722         raise err
#     723     else:
#     724         raise error("getaddrinfo returns an empty list")
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     711             if source_address:
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             return sock
#     715
#
# OSError: [Errno 49] Can't assign requested address

# %%
# I tried to use this code earlier in the function but it was not working
# I guess the error that I receive after a few lines of telephone numbers 
# is what and prevents it from working in the function.
