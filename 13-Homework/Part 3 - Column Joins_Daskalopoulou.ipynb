# %% [markdown]
# # Number 3: Columns Joins
#
# You have two datasets:
#
# * An Excel document of obesity rates, called `obesity.xlsx`
# * A shapefile of US states from the [Census Burea](https://www.census.gov/geo/maps-data/data/tiger-cart-boundary.html), unzipped into `cb_2016_us_state_500k/`
#
# You're going to make a choropleth of obesity rates in US states.
#
# **MAKE SURE YOU HAVE COMPLETED PART TWO BEFORE YOU DO THIS ONE.**
#
# ## Part Zero: Import what you need
#
# I'm not giving you any more hints!

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %matplotlib inline

# %% [markdown]
# ## Part One: Opening your datasets
#
# **Open up both files!** Think about what kind of file each one is before you try to open it.

# %%
obesity = pd.read_excel("obesity.xlsx")
obesity.head()
# Out:
#     statename   pct
# 0     Alabama  31.1
# 1      Alaska  27.7
# 2     Arizona  24.4
# 3    Arkansas  33.2
# 4  California  22.2

# %%
states = gpd.read_file("/Users/aspasiadaskalopoulou/Desktop/found/13-classwork/13-homework/cb_2016_us_state_500k/cb_2016_us_state_500k.shp")
states.head()
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD        NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00     Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00      Alaska      02
# 2  0400000US04   294198560125    1027346486    04   00     Arizona      04
# 3  0400000US05   134771517596    2960191698    05   00    Arkansas      05
# 4  0400000US06   403501101370   20466718403    06   00  California      06
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %% [markdown]
# ## Part Two: Map the states, just for fun
#
# To double-check that the states look okay, make a quick map of them.

# %%
states.plot()

# %% [markdown]
# Uh, well, let's just stick to the continental Uninted States for now. An easy way to do this is by creating a **bounding box** and filtering out the ones that aren't inside.
#
# I like to use [this dumb site](https://itouchmap.com/latlong.html) to find the latitude and longitude of specific points, but if I'm just trying to figure out a box I use [geojson.io](http://geojson.io/) and just... draw a box and see what it tells me.
#
# For example, down below I am only selecting **the northeast**. I got the boundaries by drawing a box on geojson.io. We also use our good friend **`.within`** from last time to say hey states, which ones of you are inside of the boundary box?

# %% [markdown]
# ## Part Three: Filter your states
#
# So *I* selected only states in the northeast. Now it's your job to use that new skill to **filter out any states that aren't in the continental USA.**

# %%
from shapely.geometry import Polygon

bounds = [
            [
              -132.5390625,
              52.696361078274485
            ],
            [
              -127.96875,
              31.353636941500987
            ],
            [
              -99.49218749999999,
              22.268764039073968
            ],
            [
              -79.8046875,
              24.206889622398023
            ],
            [
              -66.09375,
              35.17380831799959
            ],
            [
              -50.2734375,
              17.308687886770034
            ],
            [
              -47.4609375,
              49.83798245308484
            ],
            [
              -132.5390625,
              52.696361078274485
            ]
          ]

continental_box = Polygon(bounds)
states.to_crs({'init': 'epsg:4326'}).within(continental_box).head(10)
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# dtype: bool

# %% [markdown]
# And of course we can take those `True` and `False` values and feed them back into `states` to only get the states we're interested in. I plot them below, but you could always save them to a variable instead!

# %%
states = states[states.to_crs({'init': 'epsg:4326'}).within(continental_box)]
states
# Out:
#        AFFGEOID         ALAND        AWATER GEOID LSAD                  NAME  \
# 0   0400000US01  131173688951    4593686489    01   00               Alabama
# 2   0400000US04  294198560125    1027346486    04   00               Arizona
# 3   0400000US05  134771517596    2960191698    05   00              Arkansas
# 4   0400000US06  403501101370   20466718403    06   00            California
# 5   0400000US08  268429343790    1175112870    08   00              Colorado
# 6   0400000US09   12542638347    1815476291    09   00           Connecticut
# 7   0400000US10    5047194742    1398720828    10   00              Delaware
# 8   0400000US11     158364992      18633403    11   00  District of Columbia
# 9   0400000US13  149169848456    4741100880    13   00               Georgia
# 11  0400000US16  214042908012    2398669593    16   00                 Idaho
# 12  0400000US17  143788697679    6206693598    17   00              Illinois
# 13  0400000US18   92790545247    1536767065    18   00               Indiana
# 14  0400000US19  144667643793    1077808017    19   00                  Iowa
# 15  0400000US20  211753253104    1346235678    20   00                Kansas
# 16  0400000US24   25147754905    6983312282    24   00              Maryland
# 17  0400000US27  206232257655   18929176411    27   00             Minnesota
# 18  0400000US28  121529933533    3930505829    28   00           Mississippi
# 19  0400000US30  376964956503    3866986696    30   00               Montana
# 20  0400000US32  284329326845    2047350887    32   00                Nevada
# 21  0400000US34   19050755048    3541927612    34   00            New Jersey
# 22  0400000US35  314169362533     755722962    35   00            New Mexico
# 23  0400000US38  178711813026    4399093501    38   00          North Dakota
# 24  0400000US40  177663722167    3373836066    40   00              Oklahoma
# 25  0400000US42  115882226263    3396805575    42   00          Pennsylvania
# 26  0400000US45   77861720871    5070943755    45   00        South Carolina
# 27  0400000US46  196348407642    3380782733    46   00          South Dakota
# 28  0400000US49  212885517115    6999529104    49   00                  Utah
# 29  0400000US50   23873467535    1031124865    50   00               Vermont
# 30  0400000US54   62265597146     489902816    54   00         West Virginia
# 31  0400000US56  251464935120    1861273298    56   00               Wyoming
# 34  0400000US12  138924199212   31386038155    12   00               Florida
# 35  0400000US21  102266279759    2388770991    21   00              Kentucky
# 36  0400000US22  111904912452   23746303848    22   00             Louisiana
# 37  0400000US23   79885221885   11748755195    23   00                 Maine
# 38  0400000US25   20204442852    7130620748    25   00         Massachusetts
# 39  0400000US26  146455251245  104031574060    26   00              Michigan
# 40  0400000US29  178052653610    2487575477    29   00              Missouri
# 41  0400000US31  198972706218    1356290940    31   00              Nebraska
# 42  0400000US33   23187396994    1028678842    33   00         New Hampshire
# 43  0400000US36  122053048985   19243095591    36   00              New York
# 44  0400000US37  125921301190   13470062955    37   00        North Carolina
# 45  0400000US39  105833122995   10264595056    39   00                  Ohio
# 46  0400000US41  248604268242    6195105690    41   00                Oregon
# 47  0400000US44    2677898725    1323551636    44   00          Rhode Island
# 48  0400000US47  106797662267    2355188876    47   00             Tennessee
# 49  0400000US48  676633459408   19025991684    48   00                 Texas
# 50  0400000US51  102257320053    8528605825    51   00              Virginia
# 51  0400000US53  172113416541   12558451099    53   00            Washington
# 52  0400000US55  140273604537   29361386480    55   00             Wisconsin
#
#    STATEFP   STATENS STUSPS                                           geometry
# 0       01  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 2       04  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3       05  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4       06  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...
# 5       08  01779779     CO  POLYGON ((-109.060253 38.599328, -109.059541 3...
# 6       09  01779780     CT  (POLYGON ((-72.761427 41.242333, -72.759733 41...
# 7       10  01779781     DE  (POLYGON ((-75.565546 39.51485, -75.5617429999...
# 8       11  01702382     DC  POLYGON ((-77.119759 38.934343, -77.1125318000...
# 9       13  01705317     GA  (POLYGON ((-81.27939099999999 31.30792, -81.27...
# 11      16  01779783     ID  POLYGON ((-117.242675 44.396548, -117.234835 4...
# 12      17  01779784     IL  POLYGON ((-91.512974 40.181062, -91.511073 40....
# 13      18  00448508     IN  POLYGON ((-88.09776000000001 37.904026, -88.09...
# 14      19  01779785     IA  POLYGON ((-96.63970399999999 42.737071, -96.63...
# 15      20  00481813     KS  POLYGON ((-102.051744 40.003078, -101.916696 4...
# 16      24  01714934     MD  (POLYGON ((-76.05015299999999 37.986905, -76.0...
# 17      27  00662849     MN  (POLYGON ((-89.59205799999999 47.966683, -89.5...
# 18      28  01779790     MS  (POLYGON ((-88.502966 30.215235, -88.491759 30...
# 19      30  00767982     MT  POLYGON ((-116.049667201931 48.4403221865285, ...
# 20      32  01779793     NV  POLYGON ((-120.005743 39.22866399999999, -120....
# 21      34  01779795     NJ  POLYGON ((-75.559102 39.629056, -75.5594459999...
# 22      35  00897535     NM  POLYGON ((-109.050173 31.480004, -109.049843 3...
# 23      38  01779797     ND  POLYGON ((-104.048652 48.865734, -104.048824 4...
# 24      40  01102857     OK  POLYGON ((-103.002565 36.526588, -103.002188 3...
# 25      42  01779798     PA  POLYGON ((-80.519891 40.906661, -80.5190910000...
# 26      45  01779799     SC  (POLYGON ((-79.50794800000001 33.020076, -79.5...
# 27      46  01785534     SD  POLYGON ((-104.057698 44.997431, -104.049505 4...
# 28      49  01455989     UT  POLYGON ((-114.052962 37.592783, -114.052472 3...
# 29      50  01779802     VT  POLYGON ((-73.43773999999999 44.045006, -73.43...
# 30      54  01779805     WV  POLYGON ((-82.6431981036679 38.1690897960737, ...
# 31      56  01779807     WY  POLYGON ((-111.056888 44.866658, -111.055629 4...
# 34      12  00294478     FL  (POLYGON ((-80.176276 25.525054, -80.173949999...
# 35      21  01779786     KY  (POLYGON ((-89.405654 36.528165, -89.398685 36...
# 36      22  01629543     LA  (POLYGON ((-88.8677 29.861551, -88.86565899999...
# 37      23  01779787     ME  (POLYGON ((-67.32259499999999 44.611595, -67.3...
# 38      25  00606926     MA  (POLYGON ((-70.23405400000001 41.285653, -70.2...
# 39      26  01779789     MI  (POLYGON ((-83.98756499999999 46.092853, -83.9...
# 40      29  01779791     MO  POLYGON ((-95.773549 40.578205, -95.7685270000...
# 41      31  01779792     NE  POLYGON ((-104.053418545071 41.1705389679833, ...
# 42      33  01779794     NH  (POLYGON ((-70.617025 42.977182, -70.615288999...
# 43      36  01779796     NY  (POLYGON ((-72.0368298202051 41.24984253938471...
# 44      37  01027616     NC  (POLYGON ((-77.098485 34.647023, -77.098422976...
# 45      39  01085497     OH  (POLYGON ((-82.73570699999999 41.603361, -82.7...
# 46      41  01155107     OR  (POLYGON ((-123.598916 46.251454, -123.598414 ...
# 47      44  01219835     RI  (POLYGON ((-71.288017 41.645575, -71.286470999...
# 48      47  01325873     TN  POLYGON ((-90.31029799999999 35.004295, -90.30...
# 49      48  01779801     TX  (POLYGON ((-94.718296 29.728855, -94.717207 29...
# 50      51  01779803     VA  (POLYGON ((-75.742406 37.80835, -75.7415120000...
# 51      53  01779804     WA  (POLYGON ((-122.33164 48.020556, -122.328343 4...
# 52      55  01779806     WI  (POLYGON ((-86.95616699999999 45.355489, -86.9...

# %%
states[states.to_crs({'init': 'epsg:4326'}).within(continental_box)].plot()

# %% [markdown]
# ## Part Four: Joining your data
#
# You have some obesity data, it looks like this:

# %%
obesity.head(3)
# Out:
#   statename   pct
# 0   Alabama  31.1
# 1    Alaska  27.7
# 2   Arizona  24.4

# %% [markdown]
# You have some states, they look like this:

# %%
continental.head(3)
# Out:
#       AFFGEOID         ALAND      AWATER GEOID LSAD      NAME STATEFP  \
# 0  0400000US01  131173688951  4593686489    01   00   Alabama      01
# 2  0400000US04  294198560125  1027346486    04   00   Arizona      04
# 3  0400000US05  134771517596  2960191698    05   00  Arkansas      05
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...

# %% [markdown]
# You need to **merge them together** using [merge](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html), which is just a normal pandas thing we've done before.
#
# **THIS IS NOT A SPATIAL JOIN.** We're just saying hey, you guys both have columns that match, right? You might want to get together.
#
# All `.merge` needs is two dataframes and a `left_on`/`right_on` to specify which columns to match up. Unlike a spatial join, for most column joins it doesn't matter which one is "left" and which one is "right."

# %%
ob_st = states.merge(obesity, left_on='NAME', right_on='statename')
ob_st
# Out:
#        AFFGEOID         ALAND        AWATER GEOID LSAD                  NAME  \
# 0   0400000US01  131173688951    4593686489    01   00               Alabama
# 1   0400000US04  294198560125    1027346486    04   00               Arizona
# 2   0400000US05  134771517596    2960191698    05   00              Arkansas
# 3   0400000US06  403501101370   20466718403    06   00            California
# 4   0400000US08  268429343790    1175112870    08   00              Colorado
# 5   0400000US09   12542638347    1815476291    09   00           Connecticut
# 6   0400000US10    5047194742    1398720828    10   00              Delaware
# 7   0400000US11     158364992      18633403    11   00  District of Columbia
# 8   0400000US13  149169848456    4741100880    13   00               Georgia
# 9   0400000US16  214042908012    2398669593    16   00                 Idaho
# 10  0400000US17  143788697679    6206693598    17   00              Illinois
# 11  0400000US18   92790545247    1536767065    18   00               Indiana
# 12  0400000US19  144667643793    1077808017    19   00                  Iowa
# 13  0400000US20  211753253104    1346235678    20   00                Kansas
# 14  0400000US24   25147754905    6983312282    24   00              Maryland
# 15  0400000US27  206232257655   18929176411    27   00             Minnesota
# 16  0400000US28  121529933533    3930505829    28   00           Mississippi
# 17  0400000US30  376964956503    3866986696    30   00               Montana
# 18  0400000US32  284329326845    2047350887    32   00                Nevada
# 19  0400000US34   19050755048    3541927612    34   00            New Jersey
# 20  0400000US35  314169362533     755722962    35   00            New Mexico
# 21  0400000US38  178711813026    4399093501    38   00          North Dakota
# 22  0400000US40  177663722167    3373836066    40   00              Oklahoma
# 23  0400000US42  115882226263    3396805575    42   00          Pennsylvania
# 24  0400000US45   77861720871    5070943755    45   00        South Carolina
# 25  0400000US46  196348407642    3380782733    46   00          South Dakota
# 26  0400000US49  212885517115    6999529104    49   00                  Utah
# 27  0400000US50   23873467535    1031124865    50   00               Vermont
# 28  0400000US54   62265597146     489902816    54   00         West Virginia
# 29  0400000US56  251464935120    1861273298    56   00               Wyoming
# 30  0400000US12  138924199212   31386038155    12   00               Florida
# 31  0400000US21  102266279759    2388770991    21   00              Kentucky
# 32  0400000US22  111904912452   23746303848    22   00             Louisiana
# 33  0400000US23   79885221885   11748755195    23   00                 Maine
# 34  0400000US25   20204442852    7130620748    25   00         Massachusetts
# 35  0400000US26  146455251245  104031574060    26   00              Michigan
# 36  0400000US29  178052653610    2487575477    29   00              Missouri
# 37  0400000US31  198972706218    1356290940    31   00              Nebraska
# 38  0400000US33   23187396994    1028678842    33   00         New Hampshire
# 39  0400000US36  122053048985   19243095591    36   00              New York
# 40  0400000US37  125921301190   13470062955    37   00        North Carolina
# 41  0400000US39  105833122995   10264595056    39   00                  Ohio
# 42  0400000US41  248604268242    6195105690    41   00                Oregon
# 43  0400000US44    2677898725    1323551636    44   00          Rhode Island
# 44  0400000US47  106797662267    2355188876    47   00             Tennessee
# 45  0400000US48  676633459408   19025991684    48   00                 Texas
# 46  0400000US51  102257320053    8528605825    51   00              Virginia
# 47  0400000US53  172113416541   12558451099    53   00            Washington
# 48  0400000US55  140273604537   29361386480    55   00             Wisconsin
#
#    STATEFP   STATENS STUSPS  \
# 0       01  01779775     AL
# 1       04  01779777     AZ
# 2       05  00068085     AR
# 3       06  01779778     CA
# 4       08  01779779     CO
# 5       09  01779780     CT
# 6       10  01779781     DE
# 7       11  01702382     DC
# 8       13  01705317     GA
# 9       16  01779783     ID
# 10      17  01779784     IL
# 11      18  00448508     IN
# 12      19  01779785     IA
# 13      20  00481813     KS
# 14      24  01714934     MD
# 15      27  00662849     MN
# 16      28  01779790     MS
# 17      30  00767982     MT
# 18      32  01779793     NV
# 19      34  01779795     NJ
# 20      35  00897535     NM
# 21      38  01779797     ND
# 22      40  01102857     OK
# 23      42  01779798     PA
# 24      45  01779799     SC
# 25      46  01785534     SD
# 26      49  01455989     UT
# 27      50  01779802     VT
# 28      54  01779805     WV
# 29      56  01779807     WY
# 30      12  00294478     FL
# 31      21  01779786     KY
# 32      22  01629543     LA
# 33      23  01779787     ME
# 34      25  00606926     MA
# 35      26  01779789     MI
# 36      29  01779791     MO
# 37      31  01779792     NE
# 38      33  01779794     NH
# 39      36  01779796     NY
# 40      37  01027616     NC
# 41      39  01085497     OH
# 42      41  01155107     OR
# 43      44  01219835     RI
# 44      47  01325873     TN
# 45      48  01779801     TX
# 46      51  01779803     VA
# 47      53  01779804     WA
# 48      55  01779806     WI
#
#                                              geometry             statename  \
# 0   (POLYGON ((-88.053375 30.506987, -88.051087999...               Alabama
# 1   POLYGON ((-114.816294 32.508038, -114.814321 3...               Arizona
# 2   POLYGON ((-94.6178329666013 36.4994141203285, ...              Arkansas
# 3   (POLYGON ((-118.604415 33.478552, -118.598783 ...            California
# 4   POLYGON ((-109.060253 38.599328, -109.059541 3...              Colorado
# 5   (POLYGON ((-72.761427 41.242333, -72.759733 41...           Connecticut
# 6   (POLYGON ((-75.565546 39.51485, -75.5617429999...              Delaware
# 7   POLYGON ((-77.119759 38.934343, -77.1125318000...  District of Columbia
# 8   (POLYGON ((-81.27939099999999 31.30792, -81.27...               Georgia
# 9   POLYGON ((-117.242675 44.396548, -117.234835 4...                 Idaho
# 10  POLYGON ((-91.512974 40.181062, -91.511073 40....              Illinois
# 11  POLYGON ((-88.09776000000001 37.904026, -88.09...               Indiana
# 12  POLYGON ((-96.63970399999999 42.737071, -96.63...                  Iowa
# 13  POLYGON ((-102.051744 40.003078, -101.916696 4...                Kansas
# 14  (POLYGON ((-76.05015299999999 37.986905, -76.0...              Maryland
# 15  (POLYGON ((-89.59205799999999 47.966683, -89.5...             Minnesota
# 16  (POLYGON ((-88.502966 30.215235, -88.491759 30...           Mississippi
# 17  POLYGON ((-116.049667201931 48.4403221865285, ...               Montana
# 18  POLYGON ((-120.005743 39.22866399999999, -120....                Nevada
# 19  POLYGON ((-75.559102 39.629056, -75.5594459999...            New Jersey
# 20  POLYGON ((-109.050173 31.480004, -109.049843 3...            New Mexico
# 21  POLYGON ((-104.048652 48.865734, -104.048824 4...          North Dakota
# 22  POLYGON ((-103.002565 36.526588, -103.002188 3...              Oklahoma
# 23  POLYGON ((-80.519891 40.906661, -80.5190910000...          Pennsylvania
# 24  (POLYGON ((-79.50794800000001 33.020076, -79.5...        South Carolina
# 25  POLYGON ((-104.057698 44.997431, -104.049505 4...          South Dakota
# 26  POLYGON ((-114.052962 37.592783, -114.052472 3...                  Utah
# 27  POLYGON ((-73.43773999999999 44.045006, -73.43...               Vermont
# 28  POLYGON ((-82.6431981036679 38.1690897960737, ...         West Virginia
# 29  POLYGON ((-111.056888 44.866658, -111.055629 4...               Wyoming
# 30  (POLYGON ((-80.176276 25.525054, -80.173949999...               Florida
# 31  (POLYGON ((-89.405654 36.528165, -89.398685 36...              Kentucky
# 32  (POLYGON ((-88.8677 29.861551, -88.86565899999...             Louisiana
# 33  (POLYGON ((-67.32259499999999 44.611595, -67.3...                 Maine
# 34  (POLYGON ((-70.23405400000001 41.285653, -70.2...         Massachusetts
# 35  (POLYGON ((-83.98756499999999 46.092853, -83.9...              Michigan
# 36  POLYGON ((-95.773549 40.578205, -95.7685270000...              Missouri
# 37  POLYGON ((-104.053418545071 41.1705389679833, ...              Nebraska
# 38  (POLYGON ((-70.617025 42.977182, -70.615288999...         New Hampshire
# 39  (POLYGON ((-72.0368298202051 41.24984253938471...              New York
# 40  (POLYGON ((-77.098485 34.647023, -77.098422976...        North Carolina
# 41  (POLYGON ((-82.73570699999999 41.603361, -82.7...                  Ohio
# 42  (POLYGON ((-123.598916 46.251454, -123.598414 ...                Oregon
# 43  (POLYGON ((-71.288017 41.645575, -71.286470999...          Rhode Island
# 44  POLYGON ((-90.31029799999999 35.004295, -90.30...             Tennessee
# 45  (POLYGON ((-94.718296 29.728855, -94.717207 29...                 Texas
# 46  (POLYGON ((-75.742406 37.80835, -75.7415120000...              Virginia
# 47  (POLYGON ((-122.33164 48.020556, -122.328343 4...            Washington
# 48  (POLYGON ((-86.95616699999999 45.355489, -86.9...             Wisconsin
#
#      pct
# 0   31.1
# 1   24.4
# 2   33.2
# 3   22.2
# 4   19.1
# 5   24.0
# 6   29.4
# 7    9.9
# 8   28.0
# 9   28.1
# 10  28.3
# 11  31.3
# 12  31.6
# 13  31.0
# 14  26.7
# 15  26.5
# 16  31.5
# 17  23.8
# 18  26.3
# 19  25.6
# 20  22.8
# 21  31.3
# 22  32.5
# 23  29.5
# 24  28.3
# 25  29.6
# 26  24.5
# 27  24.8
# 28  35.2
# 29  28.0
# 30  25.2
# 31  32.9
# 32  31.9
# 33  29.2
# 34  23.0
# 35  30.2
# 36  30.4
# 37  30.0
# 38  27.3
# 39  24.9
# 40  27.2
# 41  30.5
# 42  28.1
# 43  26.4
# 44  31.5
# 45  27.9
# 46  26.7
# 47  27.7
# 48  29.8

# %% [markdown]
# ## Part Five: Mapping your data
#
# Map it. Familiar projection, nice large size, etc. Use a [nice color map](https://matplotlib.org/examples/color/colormaps_reference.html) that makes sense.
#
# The one below is Mercator - you can see the grumpy top of the USA - see if you can make it something better! Maybe find the EPSG code for an Albers Equal Area that's good for the continental United States?

# %%
ob_st.crs ={'init': 'epsg:5071'}

# %%
ax = ob_st.plot(cmap='OrRd', figsize=(20,20), linewidth=0.25, edgecolor='white')
ax.axis('off')
# Out:
# (-127.65372665, -64.059236349999992, 23.280032899999998, 50.627421099999999)

# %% [markdown]
# To get a different look, try passing `legend=True` and `scheme='Quantiles'`.

# %%
ax = ob_st.plot(column='pct', cmap='OrRd', figsize=(20,20), linewidth=0.25, edgecolor='white', legend=True, scheme='Quantiles')
ax.axis('off')
# Out:
# (-127.65372665, -64.059236349999992, 23.280032899999998, 50.627421099999999)

# %% [markdown]
# And oooone more time with `legend=True` and `scheme='equal_interval'`

# %%
ax = ob_st.plot(column='pct', cmap='OrRd', figsize=(15,15), linewidth=0.25, edgecolor='white', legend=True, scheme='equal_interval')
ax.axis('off')
# Out:
# (-127.65372665, -64.059236349999992, 23.280032899999998, 50.627421099999999)

# %% [markdown]
# ## Think about which one does the best job telling the story.
#
# We'll talk about this next class.
