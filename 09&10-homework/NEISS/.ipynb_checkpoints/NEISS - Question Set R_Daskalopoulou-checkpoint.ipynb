# %% [markdown]
# # Exercise: NEISS, Question Set R
#
# #### Summary
#
# The [National Electronic Injury Surveillance System](https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS) is a data product produced by the US Consumer Product Safety Commission. It tracks emergency room injuries related to consumer products (e.g., "a door fell on me!").
#
# #### Files
#
# - **nss15.tsv**: injury data (one injury per row)
# - **2017NEISSCodingManualCPSConlyNontrauma.pdf**: column definitions and explanations
# - **2015 Neiss data highlights.pdf**: a partial summary of the data
# - **2017ComparabilityTable.pdf**: product code definitions
# - **categories-cleaned.txt**: product code definitions in CSV format (great for joining!)
#
# #### Source
#
# https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS
#
# #### Skills
#
# - Using codebooks
# - Reading tab-separated files
# - Ignoring bad lines
# - Replacing LOTS of values
# - Merging dataframes
# - Using numpy/`np.nan`
# - Padding strings
# - String search using regular expressions

# %% [markdown]
# # Read in `nss15.tsv`
#
# Some of the lines just **aren't formatted correctly**. Maybe we can avoid those?

# %%
import pandas as pd
df = pd.read_csv('nss15.tsv', sep ="\t", error_bad_lines=False)
# Out:
# b'Skipping line 10822: expected 19 fields, saw 20\n'
# b'Skipping line 48623: expected 19 fields, saw 20\nSkipping line 62534: expected 19 fields, saw 20\n'
# b'Skipping line 103739: expected 19 fields, saw 20\n'
# b'Skipping line 135495: expected 19 fields, saw 20\nSkipping line 151678: expected 19 fields, saw 20\n'
# b'Skipping line 237135: expected 19 fields, saw 20\nSkipping line 240597: expected 19 fields, saw 20\n'
# b'Skipping line 274270: expected 19 fields, saw 20\nSkipping line 277461: expected 19 fields, saw 20\n'

# %% [markdown]
# ### Check that your dataframe has 357727 rows and 19 columns.

# %%
df.shape
# Out:
# (357727, 19)

# %% [markdown]
# ### List the columns and their data types

# %%
df.columns
# Out:
# Index(['CPSC Case #', 'trmt_date', 'psu', 'weight', 'stratum', 'age', 'sex',
#        'race', 'race_other', 'diag', 'diag_other', 'body_part', 'disposition',
#        'location', 'fmv', 'prod1', 'prod2', 'narr1', 'narr2'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CPSC Case #      int64
# trmt_date       object
# psu              int64
# weight         float64
# stratum         object
# age              int64
# sex              int64
# race             int64
# race_other      object
# diag             int64
# diag_other      object
# body_part        int64
# disposition      int64
# location         int64
# fmv              int64
# prod1            int64
# prod2          float64
# narr1           object
# narr2           object
# dtype: object

# %% [markdown]
# ### What does each column mean?

# %% [markdown]
# CPSC Case #     -  Case Number
#
# trmt_date       -  Date of Treatment
#
# psu             -  int64
#
# weight          -  Weight of Patient
#
# stratum         -  object
#
# age             -  Age of Patient
#
# sex             -  Gender of Patient
#
# race            -  Race and Ethnicity
#
# race_other      -  Other Race and/or Ethnicity
#
# diag            -  Diagnosis
#
# diag_other      -  Diagnosis
#
# body_part       -  Body Part Affected
#
# disposition     -  Disposition of Case
#
# location        -  Incident Locale
#
# fmv             -  Fire Involvement
#
# prod1           -  Product(s) Mentioned
#
# prod2           -  Product(s) Mentioned
#
# narr1           -  Comments
#
# narr2           -  Comments

# %% [markdown]
# # Cleaning up a column
#
# Take a look at the **body part** column. How many rows of each body part are there?

# %%
df.body_part.value_counts()
# Out:
# 75    58677
# 76    30992
# 79    30579
# 92    30463
# 37    20077
# 31    19518
# 35    18957
# 82    17077
# 83    15890
# 30    14822
# 33    13655
# 36    12771
# 34    11565
# 32     8888
# 85     8615
# 88     7336
# 93     7299
# 89     6145
# 77     4661
# 94     4404
# 81     4174
# 80     4016
# 0      3344
# 87     2079
# 38     1699
# 84       24
# Name: body_part, dtype: int64

# %% [markdown]
# ## Replace the numbers with the appropriate words they stand for.
#
# Those numbers are terrible - codes are fine for storage but not really for reading. **Replace the numbers with the  words they stand for.**
#
# Refer to pages 11-12 of the column definitions file, or... hey, I typed it in below!
#
# - Tip: If I've already talked about how to replace values, maybe there's a really easy way to replace a lot at once? Maybe I'll tell you if you ask me?

# %%
# 0:  'internal'
# 30: 'shoulder'
# 31: 'upper trunk'
# 32: 'elbow'
# 33: 'lower arm'
# 34: 'wrist'
# 35: 'knee'
# 36: 'lower leg'
# 37: 'ankle'
# 38: 'pubic region'
# 75: 'head'
# 76: 'face'
# 77: 'eyeball'
# 79: 'lower trunk'
# 80: 'upper arm'
# 81: 'upper leg'
# 82: 'hand'
# 83: 'foot'
# 84: '25-50% of body'
# 85: 'all parts of body'
# 87: 'not recorded'
# 88: 'mouth'
# 89: 'neck'
# 92: 'finger'
# 93: 'toe'
# 94: 'ear'

# %%
replacements = {
    0:  'internal',
    30: 'shoulder',
    31: 'upper trunk',
    32: 'elbow',
    33: 'lower arm',
    34: 'wrist',
    35: 'knee',
    36: 'lower leg',
    37: 'ankle',
    38: 'pubic region',
    75: 'head',
    76: 'face',
    77: 'eyeball',
    79: 'lower trunk',
    80: 'upper arm',
    81: 'upper leg',
    82: 'hand',
    83: 'foot',
    84: '25-50% of body',
    85: 'all parts of body',
    87: 'not recorded',
    88: 'mouth',
    89: 'neck',
    92: 'finger',
    93: 'toe',
    94: 'ear'
 }

df.body_part.replace(replacements, inplace = True)
df.head(3)
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
# 1    150734723  07/06/2015   43  83.2157       S   36    1     1        NaN
# 2    150817487  08/02/2015   51  74.8813       L   20    2     0        NaN
#
#    diag      diag_other  body_part  disposition  location  fmv  prod1   prod2  \
# 0    57             NaN  lower arm            1         9    0   1267     NaN
# 1    57             NaN      wrist            1         1    0   1439  4057.0
# 2    71  OTITIS EXTERNA        ear            1         0    0   3274     NaN
#
#                                                narr1  \
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1  L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
#
#                                                narr2
# 0                                               X IT
# 1  AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2  T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...

# %% [markdown]
# ## Confirm you have 58677 head, 30992 face, and 30579 lower trunk.
#
# Isn't this much nicer?

# %%
df.body_part.value_counts()
# Out:
# head                 58677
# face                 30992
# lower trunk          30579
# finger               30463
# ankle                20077
# upper trunk          19518
# knee                 18957
# hand                 17077
# foot                 15890
# shoulder             14822
# lower arm            13655
# lower leg            12771
# wrist                11565
# elbow                 8888
# all parts of body     8615
# mouth                 7336
# toe                   7299
# neck                  6145
# eyeball               4661
# ear                   4404
# upper leg             4174
# upper arm             4016
# internal              3344
# not recorded          2079
# pubic region          1699
# 25-50% of body          24
# Name: body_part, dtype: int64

# %% [markdown]
# ## Graph the number of each body part, but don’t included the “Not Recorded” records

# %%
# %matplotlib inline

# %%
df[df.body_part != 'not recorded'].body_part.value_counts(ascending=True).plot(kind='barh')

# %% [markdown]
# ## "Not Recorded" seems silly - change it to be `NaN` instead
#
# Don't use `na_values` for this.

# %%
import numpy as np
np.nan
# Out:
# nan

# %%
df.body_part.replace('not recorded', np.nan, inplace=True)

# %% [markdown]
# ## Graph the count of each body part, but don’t included the “Not Recorded” records
#
# Yes, again! The code you use should be different this time.

# %%
df.body_part.value_counts(ascending=True).plot(kind='barh')

# %% [markdown]
# ## For each body part, get the average age of the person who injured that part
#
# Sort from youngest to oldest

# %%
df.groupby('body_part')['age'].mean().sort_values().astype(int)
# Out:
# body_part
# pubic region         19
# ear                  24
# ankle                28
# wrist                30
# lower arm            32
# foot                 32
# knee                 34
# toe                  34
# hand                 35
# finger               35
# elbow                36
# eyeball              36
# neck                 38
# shoulder             39
# lower leg            44
# 25-50% of body       44
# upper leg            45
# upper trunk          46
# upper arm            46
# face                 47
# lower trunk          49
# mouth                51
# head                 59
# internal             62
# all parts of body    63
# Name: age, dtype: int64

# %% [markdown]
# ## Wait, "not recorded" seems really really really really old!
#
# How can the average age be like 80???? Read page 6 of the documentation. Fix the issue however you think is best, but explain what you're doing. **It would be nice to talk about this in class if you'd write it on the board!**
#
# ### Tech tip you might find useful
#
# If you want to replace a column based on a condition, pandas will probably yell at you. You get to learn this new thing called `loc` now!
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.

# %% [markdown]
# # Finding injuries

# %% [markdown]
# ## How many people were injured by "Musical instruments, electric or battery operated?"
#
# Try to do what you think would work, then see... it doesn't work. There are all kinds of reasons why it wouldn't work. Keep reading once it doesn't work for you.
#
# - Tip: `prod1` and `prod2` are the product fields
# - Tip: You can use the codebook or `cleaned-categories.txt`

# %%
df['prod1'] = df.prod1.astype(str).str.pad(4, fillchar ='0')

# %%
df['prod2'] = df.prod2.astype(str).str.pad(4, fillchar ='0')

# %%
el_mus_df = df[(df.prod1.str.match("0565")) | (df.prod2.str.match("0565"))]

# %%
el_mus_df['prod1'].value_counts().add(el_mus_df['prod2'].value_counts(), fill_value=0)
# Out:
# 0565     14.0
# 0nan     13.0
# 546.0     1.0
# dtype: float64

# %% [markdown]
# ### Did something go wrong when you read in your data?
#
# Maybe it's one of those problems like we had with `008382` in the homework, where when we read in the file it got rid of the leading zeroes? Try to read the file in again and fix that.
#
# Try to get all of the "Musical instruments, electric or battery operated" injurie again. It still won't work. Keep reading.

# %% [markdown]
# ### Looks the data export is bad!
#
# They turned `0565` into `565` when they exported it or something (so irresponsible!), and it's up to us to fix it. Pad the `prod1` and `prod2` columns to be the proper length. If you didn't actually do the task above it's going to be more difficult.

# %% [markdown]
# ## How many people were injured by musical instruments, total?
#
# Include normal musical instruments, electric musical instruments and toy musical instruments.
#
# - Tip: You can use the codebook or `cleaned-categories.txt`
# - Tip: Answer this in one line **without** using `and` or `&`.

# %%
all_mus_df = df[(df.prod1.str.match("0565")) | (df.prod2.str.match("0565")) | (df.prod1.str.match("0566")) | (df.prod2.str.match("0566")) | (df.prod1.str.match("1344")) | (df.prod2.str.match("1344"))]

# %%
all_mus_df['prod1'].value_counts().add(all_mus_df['prod2'].value_counts(), fill_value=0).sum()
# Out:
# 456.0

# %% [markdown]
# ## Out of those three, which is the most popular reason for admission?

# %%
all_mus_df['prod1'].value_counts()
# Out:
# 0566    188
# 1344     24
# 0565     14
# 1328      1
# 4076      1
# Name: prod1, dtype: int64

# %%
all_mus_df['prod2'].value_counts()
# Out:
# 0nan      210
# 1842.0      3
# 1200.0      2
# 1344.0      2
# 687.0       2
# 4071.0      1
# 1807.0      1
# 604.0       1
# 4056.0      1
# 5011.0      1
# 1211.0      1
# 1615.0      1
# 1884.0      1
# 546.0       1
# Name: prod2, dtype: int64

# %%
all_mus_df['prod1'].value_counts().add(all_mus_df['prod2'].value_counts().max(), fill_value=0)
# Out:
# 0566    398
# 1344    234
# 0565    224
# 1328    211
# 4076    211
# Name: prod1, dtype: int64

# %% [markdown]
# The most popular reason for admission is: 0566: Musical instruments, not electric or
# not battery operated or not specified.

# %% [markdown]
# ## What parts of the body are injured by musical instruments most often?

# %%
all_mus_df['body_part'].value_counts().head()
# Out:
# face           32
# head           30
# finger         23
# mouth          20
# upper trunk    19
# Name: body_part, dtype: int64

# %% [markdown]
# # Adding categories

# %% [markdown]
# ## Read in `categories-cleaned.txt`

# %%
cat_df = pd.read_csv('categories-cleaned.txt', sep =",", names = ("code", "description"))

# %%
cat_df.head()
# Out:
#    code                              description
# 0   102                 Wringer washing machines
# 1   106  Electric clothes dryers without washers
# 2   107       Gas clothes dryers without washers
# 3   110                    Electric heating pads
# 4   112           Sewing machines or accessories

# %% [markdown]
# ## How many different categories are electric/electrical/electronic?

# %%
cat_df = cat_df[cat_df.description.notnull()]

# %%
df_elec = cat_df[cat_df.description.str.contains(r".*\belectr[oi][nc].*\b.*", case=False)]
df_elec['description'].head()
# Out:
# 1               Electric clothes dryers without washers
# 3                                 Electric heating pads
# 8                                       Electric brooms
# 10    Electric water heaters (excluding immersion he...
# 14                          Electric blankets or sheets
# Name: description, dtype: object

# %%
df_elec['description'].count()
# Out:
# 55

# %%
df_elec.to_csv('electric_products.csv', index=False)

# %%
df_elec = pd.read_csv('electric_products.csv', sep =",", names = ("code", "description"))

# %%
df_elec.head()
# Out:
#    code                                        description
# 0  code                                        description
# 1   106            Electric clothes dryers without washers
# 2   110                              Electric heating pads
# 3   116                                    Electric brooms
# 4   119  Electric water heaters (excluding immersion he...

# %% [markdown]
# ## Join this with your injuries dataframes to give every row a text product code

# %%
df.head(1)
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
#
#    diag diag_other  body_part  disposition  location  fmv prod1 prod2  \
# 0    57        NaN  lower arm            1         9    0  1267  0nan
#
#                                                narr1 narr2
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...  X IT

# %%
new_df = df.merge(df_elec, left_on='prod1', right_on='code')
new_df.head()
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150537865  05/17/2015   21  15.0591       V    4    1     0        NaN
# 1    150703030  06/16/2015   52  97.9239       M   43    2     1        NaN
# 2    150755281  07/19/2015   64  15.7762       V   29    1     1        NaN
# 3    150345759  03/19/2015   21  15.0591       V   22    1     0        NaN
# 4    150858252  08/24/2015   73  83.2157       S   32    2     0        NaN
#
#    diag                        ...                                  body_part  \
# 0    59                        ...                                       face
# 1    67                        ...                          all parts of body
# 2    67                        ...                          all parts of body
# 3    59                        ...                                       head
# 4    53                        ...                                       face
#
#   disposition  location  fmv  prod1   prod2  \
# 0           1         1    0   4062    0nan
# 1           1         0    0   4062  4061.0
# 2           1         1    0   4062    0nan
# 3           1         0    0   4062    0nan
# 4           1         1    0   4062    0nan
#
#                                                narr1  \
# 0  4YM FELL WHILE ATTEMPTING TO TURN OFF THE LIGH...
# 1  ELETRICAL SHOCK 43YOF SHOCKED WHILE UNPLUGGING...
# 2  29YOM PT COMPLAIING OF BEING SHOCKED AT HOME B...
# 3  22YM T'D&F HITTING HEAD AGAINST LIGHT SWITCH N...
# 4  32YOF LAYING DOWN WITH HER DOG AND THE DOORBEL...
#
#                                           narr2  code  \
# 0                                         >>LAC  4062
# 1                             DX: ELECTROCUTION  4062
# 2                LECTROCUTION DX ELECTROCUTION#  4062
# 3                                   >>SCALP LAC  4062
# 4  ITED AND JUMPED ONTO PTS FACE CONTUSION NOSE  4062
#
#                                          description
# 0  Electrical wire or wiring systems (excluding p...
# 1  Electrical wire or wiring systems (excluding p...
# 2  Electrical wire or wiring systems (excluding p...
# 3  Electrical wire or wiring systems (excluding p...
# 4  Electrical wire or wiring systems (excluding p...
#
# [5 rows x 21 columns]

# %% [markdown]
# ## How many different injuries involved an electric/electrical/electronic product?

# %%
new_df['CPSC Case #'].count()
# Out:
# 930

# %% [markdown]
# ## Graph the most common injuries involving an electrical product

# %%
new_df['diag'].value_counts().head()
# Out:
# 59    262
# 53    143
# 71    101
# 62     96
# 57     83
# Name: diag, dtype: int64

# %%
#59: Laceration / 53: Friction burn / 71: Cartilage tear or injury (other than Strain or sprain) / 62: Closed head injury / 57: Fracture

# %% [markdown]
# ## When people get injuries using an electrical product, what part of their body is injured?

# %%
new_df['body_part'].value_counts()
# Out:
# head                 186
# face                  95
# hand                  78
# lower trunk           67
# finger                66
# all parts of body     56
# foot                  52
# upper trunk           42
# eyeball               36
# shoulder              29
# knee                  28
# lower leg             25
# mouth                 24
# lower arm             24
# toe                   23
# neck                  19
# wrist                 18
# internal              15
# ankle                 13
# elbow                  9
# upper arm              9
# upper leg              7
# ear                    4
# pubic region           2
# Name: body_part, dtype: int64

# %% [markdown]
# ## What product is most likely to injure your mouth?

# %%
df_mouth = df.loc[df.body_part == 'mouth'] 
df_mouth
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  
# 700           10YOM IN PE ACTIVITY AT SCHOOL;  DX LAC LIP
# 755     14YOM FELL OFF HIS BICYCLE AND SUSTAINED A LIP...
# 772     3 YOM INJURED MOUTH ON COAT HOOK,FELL,STRUCK H...
# 773     19 MO MALE FELL FROM A CHAIR AND HIT FACE ON T...
# 790     3YOF W LOWER LIP LAC FOLLOWING GLF ON HARDWOOD...
# 842     12MOM HIT IN THE MOUTH BY HIS BROTHER WITH A C...
# 918     4YOM WAS RUNNING AT CHURCH AND FELL INTO A CHU...
# 1002    3YOM FELL WITH DRINKING STRAW IN MOUTH;  DX PO...
# 1027    2 YO M WITH A LAC TO LIP WHEN HIT ON A COFFEE ...
# 1070                            26 Y/O M  FELL FROM  BIKE
# 1095    J/ 2 YOM. CLIMBING ON A  ROCK WALL WHEN HE BIT...
# 1219      15MOF FELL ON ENTERTAINMENT CENTER;  DX LIP LAC
# 1371    3YOF WITH LAC TO TONGUE, RAN INTO SHELF AT SCHOOL
# 1374    23 MOF TRIPPED OVER STROLLER & FELL AT *** WOR...
# 1376    21 MONTH M WITH A LAC TO LIP AFTER A UNCLE THR...
# 1478    7 YOF PLAYING OUTSIDE ON FAMILIES NEWLY CONSTR...
# ...                                                   ...
# 356582             47YOM LAC LIP- FELL DIRT BIKE- +HELMET
# 356587  7YOM WITH LACERATION TO LIP AFTER FALLING AT H...
# 356597  20MOM WALKING WITH BROOM AND FELL;  DX LIP LAC...
# 356628  36 YOF LAC TO LIP WHEN STRUCK BY A PEICE OF GL...
# 356648  6YOF TRYING TO OPEN JUICE BOTTLE USING TEETH, ...
# 356670  3 YOM A BOOKSHELF FELL AND STRUCK PT IN THE MO...
# 356680  3YOM FELL OFF A CHAIR AND SUSTAINED A LIP LACE...
# 356693  12YOF WITH LIP LACERATION. PT WAS TRIPPED BY B...
# 356897  18 MOM TRIPPED OVER DOG AND FELL ON CARPET.  D...
# 356905  3YOM-TONGUE LAC-FELL WHILE JUMPING ON A COUCH ...
# 356938  3YOM HIT MOUTH ON A TABLE, HAS LOOSE TEETH & B...
# 356947       17 MO MALE FELL ON A TOY.  DX LIP LACERATION
# 356967  16 MO FEMALE BANGED MOUTH ON A ***.  DX MOUTH ...
# 357063  26 YOM STRUCK IN THE MOUTH WITH PART OF GOLF C...
# 357126  4YOF JUMPED OFF COUCH, HIT FACE ON CORNER OF T...
# 357135  2 YO MALE FELL AND HIT MOUTH ON VASE.  DX LIP ...
# 357145  9MOM WAS JUMPING IN CRIB & HIT MOUTH ON SIDE O...
# 357289  9 MOM FELL TO FLOOR; LANDED ON MOUTH;  LACERAT...
# 357290  5YOF TRIPPED AT SCHOOL, HIT FACE ON TABLE OR D...
# 357319  7YOF SLIPPED ON WET FLOOR, FELL BITING LIP; LI...
# 357366  8 YOM DX PAIN AND LOOSE TOOTH UPPER FRONT - S/...
# 357377  2YOF FELL OFF A CHAIR 2 DAYS AGO AND HIT HER M...
# 357428  9 YO MALE PLAYING WITH A TOY IN MOUTH AND KICK...
# 357433  3 YO F PER MOTHER PT WAS RUNNING AROUND AND FE...
# 357542  11MOF FELL TO A TILE FLOOR WHILE CRAWLING AND ...
# 357547  DX LAC LIP 2YOM PATIENT WAS RUNNING & TRIPPED ...
# 357561  62YOF INC DENTAL PN TO TOOTH HAS CROWN STRUCK ...
# 357696      2YF FELL HITTING MOUTH ON THE METAL BED FRAME
# 357697  DX DENTAL INJ 4YOM PATIENT WAS STRUCK IN HIS M...
# 357700     3YOM JUMPED OFF OF BED HIT MOUTH HAS A LIP LAC
#
#                                                     narr2
# 12                      M OF POOL KNOCKING HIS TOOTH LOSE
# 73                               DX; LACERATION LOWER LIP
# 79                                                  NJURY
# 89                                      LACERATION TO LIP
# 104                                             ACERATION
# 288                                                   NaN
# 317     H. PIECE OF TRUCK GOT STUCK & MOM PULLED IT OU...
# 376                              THE FLOOR>>TONGUE LAC/SZ
# 471                                                   NaN
# 497                                                   NaN
# 534                                                   NaN
# 553      UGHT ON HIS BRACES AND PULLED OUT LIP LACERATION
# 612                                       ZURE. + HELMET.
# 686                                                   NaN
# 700                                                   NaN
# 755                                                   NaN
# 772                                        LIP LACERATION
# 773                                                   NaN
# 790     FULL THICKNESS LAC TO LOWER LIP: DX LAC LIP CO...
# 842                                 DX.   CONTUSION MOUTH
# 918                     DX LACERATION UPPER AND LOWER LIP
# 1002                                                  NaN
# 1027                                                  NaN
# 1070                                             LIP  LAC
# 1095                                        DX:TONGUE LAC
# 1219                                                  NaN
# 1371                                                  NaN
# 1374                                     DX LIP CONTUSION
# 1376                                                  NaN
# 1478    HER FACE INJURING MOUTH L CENTRAL INCISOR KNOC...
# ...                                                   ...
# 356582                                                NaN
# 356587                                   R DX LACERATION*
# 356597                                                NaN
# 356628                                AS THROWN AT A DOOR
# 356648                                      DENTAL INJURY
# 356670          PLACEMENT OF FRONT TEETH DX DENTAL INJURY
# 356680                                                NaN
# 356693                                ABLE DX LACERATION*
# 356897                                                NaN
# 356905                            R-BIT HIS TONGUE-@ HOME
# 356938                                    , DENTAL INJURY
# 356947                                                NaN
# 356967                                                NaN
# 357063  ST THE GROUND IN ANGER, DX: DENTAL TRAUMA, CHI...
# 357126                           DX: LIP LAC, LOOSE TOOTH
# 357135                                                NaN
# 357145                                                NaN
# 357289                                                 P.
# 357290                                                NaN
# 357319                                                NaN
# 357366                             WHILE TAKING A SHOWER.
# 357377  TEETH PAIN AND A BUMP ABOVE HER TEETH; DENTAL ...
# 357428                                                 FX
# 357433   HE FLOOR W/ LOOSE RT FRONT TOOTH DX TOOTH INJURY
# 357542                                                 ON
# 357547  C/O UPPER FRONT TOOTH MISSING & LAC TO THE INS...
# 357561                DENTAL DISORDER/PN, LIKELY PULPITIS
# 357696                                   >>TOOTH AVULSION
# 357697                                                NaN
# 357700                                                NaN
#
# [7336 rows x 19 columns]

# %%
df_mouth['prod1'].value_counts().head(1)
# Out:
# 1807    655
# Name: prod1, dtype: int64

# %%
df_cat = pd.read_csv('categories-cleaned.txt', sep =",", names = ("code", "description"))
df_cat.code = df_cat.code.astype(str).str.pad(4, fillchar='0')
df_cat.head()
# Out:
#    code                              description
# 0  0102                 Wringer washing machines
# 1  0106  Electric clothes dryers without washers
# 2  0107       Gas clothes dryers without washers
# 3  0110                    Electric heating pads
# 4  0112           Sewing machines or accessories

# %%
df_mouth_prod = df_mouth.merge(df_cat, left_on='prod1', right_on='code')
df_mouth_prod.drop('code', axis=1, inplace=True)
df_mouth_prod.head()
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150713631  07/04/2015   67  15.7762       V   11    1     0        NaN
# 1    150716170  06/29/2015   78  97.9239       M   12    1     2        NaN
# 2    151013724  09/05/2015    8   5.6748       C   14    1     1        NaN
# 3    150726817  07/09/2015   82  83.2157       S    8    2     1        NaN
# 4    150916244  08/01/2015   90   5.6748       C    6    1     1        NaN
#
#    diag diag_other body_part  disposition  location  fmv prod1   prod2  \
# 0    60        NaN     mouth            1         0    0  3274  1284.0
# 1    59        NaN     mouth            1         0    0  3274  1284.0
# 2    59        NaN     mouth            1         1    0  3274    0nan
# 3    53        NaN     mouth            1         0    0  3274    0nan
# 4    59        NaN     mouth            1         9    0  3274  3251.0
#
#                                                narr1  \
# 0  DX LOSS TEETH D/T TRAUME: 11YOM LOOSE LOWER R ...
# 1  12 YOM INJURED LIP,SWIMMING,RAN INTO THE WALL ...
# 2  14YOM WAS SWIMMING WITH A SNORKEL IN MOUTH AT ...
# 3  8YOF WITH BLUISH COLOR ABOVE TOP LIP STS WAS U...
# 4  6YOM-SWIMMING IN POOL SLIPPED HITTING FRONT TE...
#
#                                         narr2  \
# 0           M OF POOL KNOCKING HIS TOOTH LOSE
# 1                              LIP LACERATION
# 2  ORKLE JAMMED HIS BRACES INTO LIP; LIP LAC.
# 3                  SWIMMING, DX LIP CONTUSION
# 4        BLEEDING TO LIP. DX- LIP LACERATION.
#
#                                          description
# 0  Swimming (activity, apparel or equipment; excl...
# 1  Swimming (activity, apparel or equipment; excl...
# 2  Swimming (activity, apparel or equipment; excl...
# 3  Swimming (activity, apparel or equipment; excl...
# 4  Swimming (activity, apparel or equipment; excl...

# %%
df_mouth_prod['description'].value_counts().head(1)
# Out:
# Floors or flooring materials    655
# Name: description, dtype: int64

# %% [markdown]
# ## What product is most likely to injure your ears?

# %%
df_ear = df.loc[df.body_part == 'ear'] 
df_ear
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  age  sex  race  \
# 2         150817487  08/02/2015   51  74.8813       L   20    2     0
# 27        150913230  09/04/2015    2  15.7762       V   39    1     0
# 82        150303176  02/18/2015   24  97.9239       M    5    2     2
# 135       150456751  04/25/2015   82  83.2157       S   49    2     1
# 169       150357602  03/18/2015   54  49.2646       M    5    2     1
# 205       150809146  07/31/2015   95  15.7762       V    3    1     1
# 242       150533573  05/11/2015   11  80.8381       S   12    2     1
# 298       150858668  07/17/2015   92  83.2157       S    5    2     1
# 334       150438615  04/14/2015   18   5.6748       C    6    2     2
# 336       150536127  05/14/2015   17  15.0591       V   17    1     0
# 506       150965417  09/19/2015   18   5.6748       C    2    2     0
# 632       150442118  04/17/2015   20   5.6748       C   14    2     1
# 665       150725744  07/06/2015   78  97.9239       M   11    2     1
# 783       150814977  07/30/2015   42  74.8813       L   17    1     3
# 82            NaN    56             NaN       ear            1         1    0
# 135           NaN    56             NaN       ear            1         0    0
# 169           NaN    56             NaN       ear            1         1    0
# 205           NaN    71  OTITIS EXTERNA       ear            1         1    0
# 242           NaN    53             NaN       ear            1         0    0
# 298           NaN    71  OTITIS EXTERNA       ear            1         9    0
# 334           NaN    53             NaN       ear            1         0    0
# 336           NaN    71  OTITIS EXTERNA       ear            1         9    0
# 506       UNKNOWN    56             NaN       ear            1         0    0
# 632           NaN    56             NaN       ear            1         1    0
# 665           NaN    71  OTITIS EXTERNA       ear            1         9    0
# 783            NS    59             NaN       ear            1         0    0
# 913           NaN    56             NaN       ear            1         0    0
# 1084          NaN    56             NaN       ear            1         0    0
# 1234          NaN    62             NaN       ear            1         0    0
# 1334          NaN    71  L OTITIS MEDIA       ear            1         0    0
# 1435          NaN    59             NaN       ear            1         1    0
# 1495          NaN    59             NaN       ear            1         0    0
# 1514          NaN    56             NaN       ear            1         0    0
# 1542          NaN    56             NaN       ear            1         1    0
# 1659          NaN    56             NaN       ear            1         1    0
# 1749          NaN    59             NaN       ear            1         1    0
# 1798          NaN    71        SWELLING       ear            6         0    0
# 1807          NaN    56             NaN       ear            1         1    0
# 1856          NaN    66             NaN       ear            1         8    0
# 1906          NaN    71          OTITIS       ear            1         0    0
# 2000          NaN    53             NaN       ear            1         9    0
# 2123          NaN    59             NaN       ear            1         1    0
# ...           ...   ...             ...       ...          ...       ...  ...
# 355567        NaN    59             NaN       ear            1         1    0
# 355579        NaN    59             NaN       ear            1         8    0
# 355665        NaN    56             NaN       ear            1         1    0
# 355719        NaN    74             NaN       ear            1         1    0
# 355773        NaN    59             NaN       ear            1         1    0
# 355798        NaN    56             NaN       ear            1         1    0
# 355809        NaN    56             NaN       ear            1         0    0
# 355837        NaN    56             NaN       ear            1         1    0
# 355936        NaN    56             NaN       ear            1         1    0
# 355945        NaN    71          OTITIS       ear            1         9    0
# 356000        NaN    53             NaN       ear            1         0    0
# 356054        NaN    62             NaN       ear            1         1    0
# 356112        NaN    71  OTITIS EXTERNA       ear            1         0    0
# 356133        NaN    56             NaN       ear            1         0    0
# 356159        NaN    56             NaN       ear            1         0    0
# 356387        NaN    56             NaN       ear            1         0    0
# 356455        NaN    56             NaN       ear            1         0    0
# 356492        NaN    53             NaN       ear            1         1    0
# 356555        NaN    53             NaN       ear            1         5    0
# 356710        NaN    59             NaN       ear            1         8    0
# 356812        NaN    56             NaN       ear            1         1    0
# 357065        NaN    56             NaN       ear            1         0    0
# 357322        NaN    59             NaN       ear            1         1    0
# 357440        NaN    56             NaN       ear            1         1    0
# 357488        NaN    63             NaN       ear            1         1    0
# 357596        NaN    59             NaN       ear            1         0    0
# 357698        NaN    71            PAIN       ear            1         0    0
# 357706        NaN    59             NaN       ear            1         1    0
# 357713        NaN    56             NaN       ear            1         0    0
# 357719        NaN    59             NaN       ear            1         0    0
#
#        prod1   prod2                                              narr1  \
# 2       3274    0nan  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
#
# 355837  1137    0nan  5 YO MALE PUT PIECES OF PAPER IN EARS. DX BILA...
# 355936  1616    0nan  24 YOF C/O FOREIGN BODY RIGHT EAR, STATES SMAL...
# 355945  3274    0nan  5YOM SWIMMING IN THE GULF AND DEVELOPED PAIN I...
# 356000  0443    0nan  DX ABRASION L EAR CANAL/BLUNT TRAUMA L EAR CAN...
# 356054  1682    0nan  3 Y O M RUPTURED TYMPANIC MEMBRANE HIS SISTER ...
# 356112  3274    0nan  9YO F WITH EAR PAIN X 1 WEEK. HAS BEEN SWIMMIN...
# 356133  0546    0nan  36YM STS HE HAS A RUBBER PIECE OF HEADPHONE ST...
# 356159  1345    0nan        6 YO M WITH A ***, FB, IN EAR REMOVED IN ED
# 356387  1616    0nan  A 14YOM TO ER WITH FB TO EAR, BACK OF EARRING ...
# 356455  1616    0nan              7YOM GOT EARRING STUCK IN LT EAR LOBE
# 356492  1842    0nan                         18YOM ABR EAR - FELL STEPS
# 356555  1890    0nan  74 YM WAS RIDING AN ESCALATOR AND LOST BALANCE...
# 356710  0417    0nan  12 YO FEMALE POKED IN THE EAR WITH A FORK AT S...
# 356812  0380    0nan  68YF WAS FANNING SELF TO SLEP&FELL ASLEEP ON H...
# 357065  1394    0nan  3YOF PUT SMALL CIRCULAR WHITE OBJECTS FROM HER...
# 357322  4076    0nan  53YOF LAC TO  EAR LOBE WHEN FALL OFF BED WHILE...
# 357440  1617    0nan  6 YOIM PUT A N EAR PLUG IN LT. EAR; PIECE BROK...
# 357488  1395    0nan  2YOM FELL WITH TOY IN EAR;  DX TRAUMA TO EAR C...
# 357596  4074    0nan  4YOF- PT WITH LACERATION TO LEFT EAR FALLING O...
# 357698  1616    0nan  33 YOF INJURED EAR WEARING EARRINGS 2 DAYS AGO...
# 357706  1871    0nan  5 YOF MOTHER STATES CHILD RAN INTO A FENCE AT ...
# 357713  1936    0nan                  5YOM PUT A BB IN RIGHT EAR FB EAR
# 357719  1616    0nan  15 MOF R EARRING WAS PULLED OUT OF EAR RESULTI...
#
#                                                     narr2
# 2       T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 27                                                    NaN
# 82                                       UDITORY LT CANAL
# 135                                    DX EARRING REMOVAL
# 169                                                   NaN
# 205                                                  URT.
# 242                                                   NaN
# 298                                                   NaN
# 334                                                   NaN
# 336                                    OTITIS EXTERNA EAR
# 506                                                   NaN
# 632                                                   NaN
# 665                                                   NaN
# 783                                              /EAR LAC
# 913                                          DX FB IN EAR
# 1084                                                  NaN
# 1234                         UPTURE/OTALGIA EAR PN; R EAR
# 1334    E CHILD WAS SWIMMING THIS WEEK&HAD BILAT TYMPA...
# 1435                                              LAC EAR
# 1495    ND THE EAR BY A TREE BRANCH, ALSO DRANK 2 BEER...
# 1514                                                  NaN
# 1542                                     FOREIGN BODY EAR
# 1659                                     FOREIGN BODY EAR
# 1749                                                  NaN
# 1798                                   >>EARLOBE SWELLING
# 1807                                                  NaN
# 1856          F THE BED MORE CRANKY DX BLEEDING EAR CANAL
# 1906                                                  NaN
# 2000    SO ACCIDENTALLY PUNCHED ON EAR YESTERDAY DX OT...
# 2123                                      E.  DX; EAR LAC
# ...                                                   ...
# 355567                                                NaN
# 355579            MISSING FROM LT. EAR.  DX; LT. EAR LAC.
# 355665                               DX  FOREIGN BODY EAR
# 355719                             CONTACT DERMATITIS EAR
# 355773                                                NaN
# 355798                                                NaN
# 355809  SWOLLEN & PAINFUL, STUD IS STUCK IN EARLOBE. D...
# 355837                                             S    B
# 355936  FELL INTO EAR WHILE SHE WAS SLEEPING, DX: FORE...
# 355945                                                NaN
# 356000       TTING STRAW IN L EAR; C/O BLOOD IN THE L EAR
# 356054                                                 AR
# 356112                                              ERNA.
# 356133                                       >>FB REMOVAL
# 356159                                                NaN
# 356387                                                NaN
# 356455                                                NaN
# 356492                                                NaN
# 356555                                    DX EAR ABRASION
# 356710                                                NaN
# 356812  OF THE SPINES IN HAND FAN LODGED INTO EAR>>FB ...
# 357065  INTO HER BILATERAL EARS SEVERAL DAYS AGO; FORE...
# 357322                                         DX EAR LAC
# 357440                                                AR.
# 357488                                                NaN
# 357596              LEFT EAR. DX- LACERATION TO LEFT EAR.
# 357698                                                NaN
# 357706                         DX LACERATION TO RIGHT EAR
# 357713                                                NaN
# 357719                                     TO BACK OF EAR
#
# [4404 rows x 19 columns]

# %%
df_ear['prod1'].value_counts().head(1)
# Out:
# 1616    1209
# Name: prod1, dtype: int64

# %%
df_ear_prod = df_ear.merge(df_cat, left_on='prod1', right_on='code')
df_ear_prod.drop('code', axis=1, inplace=True)
df_ear_prod.head()
# Out:
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150817487  08/02/2015   51  74.8813       L   20    2     0        NaN
# 1    150913230  09/04/2015    2  15.7762       V   39    1     0        NaN
# 2    150809146  07/31/2015   95  15.7762       V    3    1     1        NaN
# 3    150858668  07/17/2015   92  83.2157       S    5    2     1        NaN
# 4    150536127  05/14/2015   17  15.0591       V   17    1     0        NaN
#
#    diag      diag_other body_part  disposition  location  fmv prod1 prod2  \
# 0    71  OTITIS EXTERNA       ear            1         0    0  3274  0nan
# 1    71          OTITIS       ear            1         0    0  3274  0nan
# 2    71  OTITIS EXTERNA       ear            1         1    0  3274  0nan
# 3    71  OTITIS EXTERNA       ear            1         9    0  3274  0nan
# 4    71  OTITIS EXTERNA       ear            1         9    0  3274  0nan
#
#                                                narr1  \
# 0  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 1  39YOM DOING ALOT OF SWIMMING AND NOW EARS HURT...
# 2  LEFT OTITIS EXTERNA.3YOM WAS TAKING SWIMMING L...
# 3  5YOF HAS BEEN SWIMMING A LOT NOW CO EAR PAIN D...
# 4                17 YO M SWIMMING DEVELOPED EAR PAIN
#
#                                                narr2  \
# 0  T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 1                                                NaN
# 2                                               URT.
# 3                                                NaN
# 4                                 OTITIS EXTERNA EAR
#
#                                          description
# 0  Swimming (activity, apparel or equipment; excl...
# 1  Swimming (activity, apparel or equipment; excl...
# 2  Swimming (activity, apparel or equipment; excl...
# 3  Swimming (activity, apparel or equipment; excl...
# 4  Swimming (activity, apparel or equipment; excl...

# %%
df_ear_prod['description'].value_counts().head(1)
# Out:
# Jewelry (excluding watches)    1209
# Name: description, dtype: int64
