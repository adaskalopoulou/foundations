# %% [markdown]
# # Homework 14 Group TWO

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %matplotlib inline

# %% [markdown]
# ### states file

# %%
states = gpd.read_file("/Users/aspasiadaskalopoulou/Desktop/Lede foundations/14-classwork/14-homework-powerplants/cb_2016_us_state_500k/cb_2016_us_state_500k.shp")
states.head()
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD        NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00     Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00      Alaska      02
# 2  0400000US04   294198560125    1027346486    04   00     Arizona      04
# 3  0400000US05   134771517596    2960191698    05   00    Arkansas      05
# 4  0400000US06   403501101370   20466718403    06   00  California      06
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
states.crs
# Out:
# {'init': 'epsg:4269'}

# %%
states = states[(states.STUSPS != 'AK') & (states.STUSPS != 'HI') & (states.STUSPS != 'VI') & (states.STUSPS != 'AS') & (states.STUSPS != 'PR') & (states.STUSPS != 'GU') & (states.STUSPS != 'MP')]

# %%
states.head(2)
# Out:
#       AFFGEOID         ALAND      AWATER GEOID LSAD     NAME STATEFP  \
# 0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 2  0400000US04  294198560125  1027346486    04   00  Arizona      04
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...

# %% [markdown]
# ### powerplants.csv

# %%
df_pp = pd.read_csv("powerplants.csv")
df_pp.head(1)
# Out:
#    Plant_Code    Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 0           2  Bankhead Dam  Alabama Power Co         195  Electric Utility
#
#         City      County    Zip          Street_Add     PrimSource    ...      \
# 0  Northport  Tuscaloosa  35476  19001 Lock 17 Road  hydroelectric    ...
#
#    Solar_MW  Wind_MW  Geo_MW  Other_MW             source_des  \
# 0       0.0      0.0     NaN       NaN  Hydroelectric = 56 MW
#
#                     tech_desc                         Source  Period  \
# 0  Conventional Hydroelectric  EIA-860, EIA-860M and EIA-923  201607
#
#     Latitude  Longitude
# 0  33.458665 -87.356823
#
# [1 rows x 28 columns]

# %%
points = df_pp.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
geo_pp = gpd.GeoDataFrame(df_pp, geometry=points)
geo_pp.crs = {'init': 'epsg:4269'}
geo_pp.head(1)
# Out:
#    Plant_Code    Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 0           2  Bankhead Dam  Alabama Power Co         195  Electric Utility
#
#         City      County    Zip          Street_Add     PrimSource  \
# 0  Northport  Tuscaloosa  35476  19001 Lock 17 Road  hydroelectric
#
#                    ...                   Wind_MW  Geo_MW  Other_MW  \
# 0                  ...                       0.0     NaN       NaN
#
#               source_des                   tech_desc  \
# 0  Hydroelectric = 56 MW  Conventional Hydroelectric
#
#                           Source  Period   Latitude  Longitude  \
# 0  EIA-860, EIA-860M and EIA-923  201607  33.458665 -87.356823
#
#                                geometry
# 0  POINT (-87.35682299999999 33.458665)
#
# [1 rows x 29 columns]

# %% [markdown]
# ### pm25_annual_fixed.csv

# %%
df_pm25 = pd.read_csv("pm25_annual_fixed.csv")
pd.set_option('display.max_columns', 999)
df_pm25.head(1)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           88101    1  30.497478
#
#    Longitude  Datum            Parameter Name Sample Duration  \
# 0 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR
#
#   Pollutant Standard Metric Used  \
# 0  PM25 24-hour 2012  Daily Mean
#
#                                          Method Name  Year  \
# 0  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2017
#
#               Units of Measure Event Type  Observation Count  \
# 0  Micrograms/cubic meter (LC)  No Events                 28
#
#    Observation Percent Completeness Indicator  Valid Day Count  \
# 0                   23                      N               28
#
#    Required Day Count  Exceptional Data Count  Null Data Count  \
# 0                 122                       0                2
#
#    Primary Exceedance Count  Secondary Exceedance Count  \
# ...

# %%
df_pm25.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Metric Used', 'Method Name', 'Year',
#        'Units of Measure', 'Event Type', 'Observation Count',
#        'Observation Percent', 'Completeness Indicator', 'Valid Day Count',
#        'Required Day Count', 'Exceptional Data Count', 'Null Data Count',
#        'Primary Exceedance Count', 'Secondary Exceedance Count',
#        'Certification Indicator', 'Num Obs Below MDL', 'Arithmetic Mean',
#        'Arithmetic Standard Dev', '1st Max Value', '1st Max DateTime',
#        '2nd Max Value', '2nd Max DateTime', '3rd Max Value',
#        '3rd Max DateTime', '4th Max Value', '4th Max DateTime',
#        '1st Max Non Overlapping Value', '1st NO Max DateTime',
#        '2nd Max Non Overlapping Value', '2nd NO Max DateTime',
#        '99th Percentile', '98th Percentile', '95th Percentile',
# ...

# %% [markdown]
# ### Total Carbon Dioxide Emissions-StateRankings.csv

# %%
df_co2 = pd.read_csv("Total Carbon Dioxide Emissions-StateRankings.csv")
# Total Carbon Dioxide Emissions, million metric tons
df_co2.head(1)
# Out:
#    Rank State    CO2
# 0     1    TX  642.0

# %% [markdown]
# ### annual_conc_by_monitor_2017.csv

# %%
df_stations = pd.read_csv("annual_conc_by_monitor_2017.csv")
df_stations.head(1)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           44201    1  30.497478
#
#    Longitude  Datum Parameter Name Sample Duration       Pollutant Standard  \
# 0 -87.880258  NAD83          Ozone          1 HOUR  Ozone 1-hour Daily 2005
#
#                                          Metric Used  \
# 0  Daily maxima of observed hourly values (betwee...
#
#                               Method Name  Year   Units of Measure Event Type  \
# 0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  2017  Parts per million  No Events
#
#    Observation Count  Observation Percent Completeness Indicator  \
# 0                666                   12                      N
#
#    Valid Day Count  Required Day Count  Exceptional Data Count  \
# 0               29                 245                       0
#
#    Null Data Count  Primary Exceedance Count  Secondary Exceedance Count  \
# ...

# %% [markdown]
# ## 1. How many power plants are in each state?

# %%
states_pp = gpd.sjoin(geo_pp, states, how='left', op='within')
states_pp.head(1)
# Out:
#    Plant_Code    Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 0           2  Bankhead Dam  Alabama Power Co         195  Electric Utility
#
#         City      County    Zip          Street_Add     PrimSource  Total_MW  \
# 0  Northport  Tuscaloosa  35476  19001 Lock 17 Road  hydroelectric      56.0
#
#    Coal_MW  NG_MW  Crude_MW  Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  \
# 0      0.0    0.0       0.0     NaN      56.0         0.0         0.0
#
#    Solar_MW  Wind_MW  Geo_MW  Other_MW             source_des  \
# 0       0.0      0.0     NaN       NaN  Hydroelectric = 56 MW
#
#                     tech_desc                         Source  Period  \
# 0  Conventional Hydroelectric  EIA-860, EIA-860M and EIA-923  201607
#
#     Latitude  Longitude                              geometry index_right  \
# 0  33.458665 -87.356823  POINT (-87.35682299999999 33.458665)           0
#
#       AFFGEOID         ALAND        AWATER GEOID LSAD     NAME STATEFP  \
# ...

# %%
states_pp.columns
# Out:
# Index(['Plant_Code', 'Plant_Name', 'Utility_Na', 'Utility_ID', 'sector_nam',
#        'City', 'County', 'Zip', 'Street_Add', 'PrimSource', 'Total_MW',
#        'Coal_MW', 'NG_MW', 'Crude_MW', 'Bio_MW', 'Hydro_MW', 'HydroPS_MW',
#        'Nuclear_MW', 'Solar_MW', 'Wind_MW', 'Geo_MW', 'Other_MW', 'source_des',
#        'tech_desc', 'Source', 'Period', 'Latitude', 'Longitude', 'geometry',
#        'index_right', 'AFFGEOID', 'ALAND', 'AWATER', 'GEOID', 'LSAD', 'NAME',
#        'STATEFP', 'STATENS', 'STUSPS'],
#       dtype='object')

# %%
states_pp['NAME'].value_counts()
# Out:
# California              1222
# North Carolina           461
# Texas                    396
# New York                 372
# Minnesota                274
# Massachusetts            254
# Iowa                     222
# Michigan                 219
# New Jersey               207
# Pennsylvania             207
# Illinois                 200
# Wisconsin                174
# Colorado                 153
# Ohio                     148
# Oregon                   145
# Florida                  144
# Georgia                  139
# Washington               138
# Idaho                    136
# Indiana                  133
# Virginia                 131
# Kansas                   129
# Missouri                 117
# Arizona                  113
# Nebraska                  98
# Maine                     97
# South Carolina            95
# Oklahoma                  94
# New Mexico                92
# Utah                      89
# Connecticut               88
# Louisiana                 84
# ...

# %% [markdown]
# ## 2. Which power plants are in New York?

# %%
states_pp_ny = states_pp.loc[states_pp['NAME'] == 'New York']
pd.set_option('display.max_rows', 999)
states_pp_ny['Plant_Name']
# Out:
# 49                                       Ashokan
# 363                    Central Hudson High Falls
# 387                          Upper Mechanicville
# 469                            Jarvis (Hinckley)
# 1169               Danskammer Generating Station
# 1170                                   Dashville
# 1171                                   Neversink
# 1172                                 South Cairo
# 1173                                    Sturgeon
# 1174                              West Coxsackie
# 1175              Arthur Kill Generating Station
# 1176                                  East River
# 1177             Gowanus Gas Turbines Generating
# 1178                               Hudson Avenue
# 1179                              Indian Point 2
# 1180             Narrows Gas Turbines Generating
# 1181                                  Ravenswood
# 1182                                 59th Street
# 1183                                 74th Street
# ...

# %% [markdown]
# ## 3. Which state has the most hydroelectric power plants?

# %%
states_pp_hydro = states_pp.loc[states_pp['PrimSource'] == 'hydroelectric']
states_pp_hydro.head(1)
# Out:
#    Plant_Code    Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 0           2  Bankhead Dam  Alabama Power Co         195  Electric Utility
#
#         City      County    Zip          Street_Add     PrimSource  Total_MW  \
# 0  Northport  Tuscaloosa  35476  19001 Lock 17 Road  hydroelectric      56.0
#
#    Coal_MW  NG_MW  Crude_MW  Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  \
# 0      0.0    0.0       0.0     NaN      56.0         0.0         0.0
#
#    Solar_MW  Wind_MW  Geo_MW  Other_MW             source_des  \
# 0       0.0      0.0     NaN       NaN  Hydroelectric = 56 MW
#
#                     tech_desc                         Source  Period  \
# 0  Conventional Hydroelectric  EIA-860, EIA-860M and EIA-923  201607
#
#     Latitude  Longitude                              geometry index_right  \
# 0  33.458665 -87.356823  POINT (-87.35682299999999 33.458665)           0
#
#       AFFGEOID         ALAND        AWATER GEOID LSAD     NAME STATEFP  \
# ...

# %%
states_pp_hydro.groupby('NAME')['Plant_Code'].count().sort_values(ascending=False).head(1)
# Out:
# NAME
# California    245
# Name: Plant_Code, dtype: int64

# %% [markdown]
# ## 4. Which state produces the most energy from coal?

# %%
states_pp_coal = states_pp.loc[states_pp['PrimSource'] == 'coal']
states_pp_coal.head(1)
# Out:
#    Plant_Code Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 1           3      Barry  Alabama Power Co         195  Electric Utility
#
#     City  County    Zip        Street_Add PrimSource  Total_MW  Coal_MW  \
# 1  Bucks  Mobile  36512  North Highway 43       coal    2160.5   1088.5
#
#     NG_MW  Crude_MW  Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  Solar_MW  \
# 1  1072.0       0.0     NaN       0.0         0.0         0.0       0.0
#
#    Wind_MW  Geo_MW  Other_MW                               source_des  \
# 1      0.0     NaN       NaN  Coal = 1088.5 MW, Natural Gas = 1072 MW
#
#                                            tech_desc  \
# 1  Conventional Steam Coal; Natural Gas Fired Com...
#
#                           Source  Period  Latitude  Longitude  \
# 1  EIA-860, EIA-860M and EIA-923  201607   31.0069   -88.0103
#
#                    geometry index_right     AFFGEOID         ALAND  \
# 1  POINT (-88.0103 31.0069)           0  0400000US01  1.311737e+11
# ...

# %%
states_pp_coal.groupby('NAME')['Plant_Code'].count().sort_values(ascending=False).head(1)
# Out:
# NAME
# Pennsylvania    24
# Name: Plant_Code, dtype: int64

# %% [markdown]
# ## 5. Map states with nuclear power plants in red, and states without in grey.

# %%
states_pp2 = gpd.sjoin(states, geo_pp, how='left', op='contains')

# %%
states_pp2.head(1)
# Out:
#       NAME     AFFGEOID         ALAND      AWATER GEOID LSAD STATEFP  \
# 0  Alabama  0400000US01  131173688951  4593686489    01   00      01
#
#     STATENS STUSPS                                           geometry  \
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
#
#    Nuclear_sum  Total_sum  Wind_sum  index_right  Plant_Code  Plant_Name  \
# 0          NaN    29654.0       0.0           12          16  Martin Dam
#
#          Utility_Na  Utility_ID        sector_nam       City  County    Zip  \
# 0  Alabama Power Co         195  Electric Utility  Dadeville  Elmore  36078
#
#            Street_Add     PrimSource  Total_MW  Coal_MW  NG_MW  Crude_MW  \
# 0  675 Overlook Drive  hydroelectric     186.0      0.0    0.0       0.0
#
#    Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  Solar_MW  Wind_MW  Geo_MW  \
# 0     NaN     186.0         0.0         0.0       0.0      0.0     NaN
#
#    Other_MW              source_des                   tech_desc  \
# ...

# %%
states_pp2.groupby('NAME')['Nuclear_MW'].sum().head()
# Out:
# NAME
# Alabama       5066.4
# Arizona       3937.0
# Arkansas      1808.5
# California    2240.0
# Colorado         0.0
# Name: Nuclear_MW, dtype: float64

# %%
states.set_index('NAME', inplace=True)
states.head()
# Out:
#                AFFGEOID         ALAND       AWATER GEOID LSAD STATEFP  \
# NAME
# Alabama     0400000US01  131173688951   4593686489    01   00      01
# Arizona     0400000US04  294198560125   1027346486    04   00      04
# Arkansas    0400000US05  134771517596   2960191698    05   00      05
# California  0400000US06  403501101370  20466718403    06   00      06
# Colorado    0400000US08  268429343790   1175112870    08   00      08
#
#              STATENS STUSPS  \
# NAME
# Alabama     01779775     AL
# Arizona     01779777     AZ
# Arkansas    00068085     AR
# California  01779778     CA
# Colorado    01779779     CO
#
#                                                      geometry  Nuclear_sum  \
# NAME
# Alabama     (POLYGON ((-88.053375 30.506987, -88.051087999...          NaN
# Arizona     POLYGON ((-114.816294 32.508038, -114.814321 3...          NaN
# Arkansas    POLYGON ((-94.6178329666013 36.4994141203285, ...          NaN
# ...

# %%
states['Nuclear_sum'] = states_pp2.groupby('NAME')['Nuclear_MW'].sum()
states.head()
# Out:
#                AFFGEOID         ALAND       AWATER GEOID LSAD STATEFP  \
# NAME
# Alabama     0400000US01  131173688951   4593686489    01   00      01
# Arizona     0400000US04  294198560125   1027346486    04   00      04
# Arkansas    0400000US05  134771517596   2960191698    05   00      05
# California  0400000US06  403501101370  20466718403    06   00      06
# Colorado    0400000US08  268429343790   1175112870    08   00      08
#
#              STATENS STUSPS  \
# NAME
# Alabama     01779775     AL
# Arizona     01779777     AZ
# Arkansas    00068085     AR
# California  01779778     CA
# Colorado    01779779     CO
#
#                                                      geometry  Nuclear_sum  \
# NAME
# Alabama     (POLYGON ((-88.053375 30.506987, -88.051087999...       5066.4
# Arizona     POLYGON ((-114.816294 32.508038, -114.814321 3...       3937.0
# Arkansas    POLYGON ((-94.6178329666013 36.4994141203285, ...       1808.5
# ...

# %%
states.reset_index(inplace=True)

# %%
ax = states.plot(column='Nuclear_sum', cmap='Reds', figsize=(20,20))
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)

# %% [markdown]
# TO GET ACCURATE COLORS:

# %%
with_nuclear = states_pp2[(states_pp2['Nuclear_MW'] > 0)]

# %%
ax= states.plot(color='grey')
with_nuclear.plot(column='Nuclear_MW', color='red', figsize=(20,20), ax=ax)
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)

# %% [markdown]
# ## 6. Make a map of carbon dioxide emissions by state, with low emissions being light orange and high emissions being orange.

# %%
states_co = states.merge(df_co2, how='left', left_on='STUSPS', right_on='State')
states_co.head(1)
# Out:
#       AFFGEOID         ALAND      AWATER GEOID LSAD STATEFP   STATENS STUSPS  \
# 0  0400000US01  131173688951  4593686489    01   00      01  01779775     AL
#
#                                             geometry  Nuclear_sum  Total_sum  \
# 0  (POLYGON ((-88.053375 30.506987, -88.051087999...          NaN    29654.0
#
#    Wind_sum  Rank State    CO2
# 0       0.0    15    AL  123.0

# %%
states_co.plot(column='CO2', cmap='Oranges', figsize=(20,20))
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)

# %% [markdown]
# ## 7. Make a map of total energy produced by each state, with little being a light color and high emissions being a brighter/darker color.

# %%
states_pp2.groupby('NAME')['Total_MW'].sum().head()
# Out:
# NAME
# Alabama       29654.0
# Arizona       27083.4
# Arkansas      14706.7
# California    76586.9
# Colorado      15807.9
# Name: Total_MW, dtype: float64

# %%
states.set_index('NAME', inplace=True)
states.head()
# Out:
#                AFFGEOID         ALAND       AWATER GEOID LSAD STATEFP  \
# NAME
# Alabama     0400000US01  131173688951   4593686489    01   00      01
# Arizona     0400000US04  294198560125   1027346486    04   00      04
# Arkansas    0400000US05  134771517596   2960191698    05   00      05
# California  0400000US06  403501101370  20466718403    06   00      06
# Colorado    0400000US08  268429343790   1175112870    08   00      08
#
#              STATENS STUSPS  \
# NAME
# Alabama     01779775     AL
# Arizona     01779777     AZ
# Arkansas    00068085     AR
# California  01779778     CA
# Colorado    01779779     CO
#
#                                                      geometry  Nuclear_sum
# NAME
# Alabama     (POLYGON ((-88.053375 30.506987, -88.051087999...       5066.4
# Arizona     POLYGON ((-114.816294 32.508038, -114.814321 3...       3937.0
# Arkansas    POLYGON ((-94.6178329666013 36.4994141203285, ...       1808.5
# ...

# %%
states['Total_sum'] = states_pp2.groupby('NAME')['Total_MW'].sum()
states.head()
# Out:
#                AFFGEOID         ALAND       AWATER GEOID LSAD STATEFP  \
# NAME
# Alabama     0400000US01  131173688951   4593686489    01   00      01
# Arizona     0400000US04  294198560125   1027346486    04   00      04
# Arkansas    0400000US05  134771517596   2960191698    05   00      05
# California  0400000US06  403501101370  20466718403    06   00      06
# Colorado    0400000US08  268429343790   1175112870    08   00      08
#
#              STATENS STUSPS  \
# NAME
# Alabama     01779775     AL
# Arizona     01779777     AZ
# Arkansas    00068085     AR
# California  01779778     CA
# Colorado    01779779     CO
#
#                                                      geometry  Nuclear_sum  \
# NAME
# Alabama     (POLYGON ((-88.053375 30.506987, -88.051087999...       5066.4
# Arizona     POLYGON ((-114.816294 32.508038, -114.814321 3...       3937.0
# Arkansas    POLYGON ((-94.6178329666013 36.4994141203285, ...       1808.5
# ...

# %%
ax = states.plot(column='Total_sum', cmap='Blues', figsize=(20,20))
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)

# %% [markdown]
# ## 8. Make a map of total wind (or solar or coal) energy produced by each state, with little being a light color and high emissions being a brighter/darker color.

# %%
states_pp2.groupby('NAME')['Wind_MW'].sum().head()
# Out:
# NAME
# Alabama          0.0
# Arizona        267.3
# Arkansas         0.0
# California    5720.9
# Colorado      2961.8
# Name: Wind_MW, dtype: float64

# %%
states['Wind_sum'] = states_pp2.groupby('NAME')['Wind_MW'].sum()

# %%
ax = states.plot(column='Wind_sum', cmap='Purples', figsize=(20,20))
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)

# %%
states.reset_index(inplace=True)

# %% [markdown]
# ## 9. Make a map of average air quality of each states, with high quality being light red and low quality being dark red

# %%
df_pm25.head(1)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           88101    1  30.497478
#
#    Longitude  Datum            Parameter Name Sample Duration  \
# 0 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR
#
#   Pollutant Standard Metric Used  \
# 0  PM25 24-hour 2012  Daily Mean
#
#                                          Method Name  Year  \
# 0  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2017
#
#               Units of Measure Event Type  Observation Count  \
# 0  Micrograms/cubic meter (LC)  No Events                 28
#
#    Observation Percent Completeness Indicator  Valid Day Count  \
# 0                   23                      N               28
#
#    Required Day Count  Exceptional Data Count  Null Data Count  \
# 0                 122                       0                2
#
#    Primary Exceedance Count  Secondary Exceedance Count  \
# ...

# %%
points = df_pm25.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
geo_pm25 = gpd.GeoDataFrame(df_pm25, geometry=points)
geo_pm25.crs = {'init': 'epsg:4269'}
geo_pm25.head(3)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           88101    1  30.497478
# 1           1           27         1           88101    1  33.284928
# 2           1           33      1002           88101    1  34.762619
#
#    Longitude  Datum            Parameter Name Sample Duration  \
# 0 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR
# 1 -85.803608  NAD83  PM2.5 - Local Conditions         24 HOUR
# 2 -87.638097  NAD83  PM2.5 - Local Conditions         24 HOUR
#
#   Pollutant Standard Metric Used  \
# 0  PM25 24-hour 2012  Daily Mean
# 1  PM25 24-hour 2012  Daily Mean
# 2  PM25 24-hour 2012  Daily Mean
#
#                                          Method Name  Year  \
# 0  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2017
# 1  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2017
# 2  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2017
#
# ...

# %%
states_pm25 = gpd.sjoin(states, geo_pm25, how='left', op='contains')
states_pm25.head(1)
# Out:
#       NAME     AFFGEOID         ALAND      AWATER GEOID LSAD STATEFP  \
# 0  Alabama  0400000US01  131173688951  4593686489    01   00      01
#
#     STATENS STUSPS                                           geometry  \
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
#
#    Nuclear_sum  Total_sum  Wind_sum  aver_air_quality  worst_air_quality  \
# 0       5066.4    29654.0       0.0               NaN                NaN
#
#   index_right  State Code  County Code  Site Num  Parameter Code  POC  \
# 0          12         1.0         97.0       3.0         88101.0  1.0
#
#     Latitude  Longitude  Datum            Parameter Name Sample Duration  \
# 0  30.770181 -88.087761  NAD83  PM2.5 - Local Conditions         24 HOUR
#
#   Pollutant Standard Metric Used  \
# 0  PM25 24-hour 2012  Daily Mean
#
#                                          Method Name    Year  \
# 0  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2017.0
#
# ...

# %%
states_pm25.groupby('NAME')['Arithmetic Mean'].mean().head()
# Out:
# NAME
# Alabama       8.600705
# Arizona       7.126441
# Arkansas      7.344940
# California    9.353585
# Colorado      5.868046
# Name: Arithmetic Mean, dtype: float64

# %%
states.set_index('NAME', inplace=True)

# %%
states['aver_air_quality'] = states_pm25.groupby('NAME')['Arithmetic Mean'].mean()
states.head(1)
# Out:
#             AFFGEOID         ALAND      AWATER GEOID LSAD STATEFP   STATENS  \
# NAME
# Alabama  0400000US01  131173688951  4593686489    01   00      01  01779775
#
#         STUSPS                                           geometry  \
# NAME
# Alabama     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
#
#          Nuclear_sum  Total_sum  Wind_sum  aver_air_quality  worst_air_quality
# NAME
# Alabama       5066.4    29654.0       0.0          8.600705                NaN

# %%
ax = states.plot(column='aver_air_quality', cmap='Reds', figsize=(20,20))
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)

# %% [markdown]
# ## 10. Make a map of worst air quality measured in each state, with high quality being light red and low quality being dark red

# %%
states_pm25.groupby('NAME')['1st Max Value'].max().head()
# Out:
# NAME
# Alabama       47.7
# Arizona       21.5
# Arkansas      16.6
# California    46.4
# Colorado      26.2
# Name: 1st Max Value, dtype: float64

# %%
states['worst_air_quality'] = states_pm25.groupby('NAME')['1st Max Value'].max()

# %%
ax = states.plot(column='worst_air_quality', cmap='gist_heat', figsize=(20,20))
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)
